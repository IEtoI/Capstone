# %% [markdown]
# # Capstone Project - Predicting Hosuing Prices in Moscow

# %% [markdown]
# <p>Loading the datasets:</p>
#     <ul><li><p>train.csv</p></li>
#     <li><p>test.csv</p></li>
#     <li><p>macro.csv</p></li></ul>

# %%
#general
import time

#visuals
# %pylab inline
import missingno as msn
import seaborn as sns
sns.set(style="whitegrid", color_codes = True)

#data prep
import pandas as pd 
import numpy as np

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

#metrics
from sklearn.metrics import mean_squared_error

#ml algos
import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso, Ridge
 
cmap = sns.diverging_palette(h_neg=210, h_pos=350, s=90, l=30, as_cmap=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\palettes.py:725: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   pal = _ColorPalette(pal(np.linspace(0, 1, n_colors)))
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\palettes.py:725: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   pal = _ColorPalette(pal(np.linspace(0, 1, n_colors)))

# %%
#loading train dataset
with open("train.csv", 'r') as f:
    train_df = pd.read_csv(f,  parse_dates=['timestamp'])
#loading test dataset
with open("test.csv", 'r') as f:
    test_df = pd.read_csv(f,  parse_dates=['timestamp'])
    #loading macro dataset
with open("macro.csv", 'r') as f:
    macro_df = pd.read_csv(f,  parse_dates=['timestamp'])

# %% [markdown]
# # Part 1 - Prepocessing
#
# ### So before we go into in depth analysis of the data lets have a first quick at the data

# %%
display(train_df.head())
display(test_df.head())
display(macro_df.head())
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\IPython\core\formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# C:\Users\Wegee\Anaconda3\lib\site-packages\IPython\core\formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
#    id  timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1 2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2 2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3 2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4 2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5 2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq    ...      cafe_count_5000_price_2500  \
# 0       NaN       NaN    ...                               9
# 1       NaN       NaN    ...                              15
# 2       NaN       NaN    ...                              10
# 3       NaN       NaN    ...                              11
# 4       NaN       NaN    ...                             319
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                          4                          0
# 1                          3                          0
# 2                          3                          0
# 3                          2                          1
# 4                        108                         17
#
#    big_church_count_5000  church_count_5000  mosque_count_5000  \
# 0                     13                 22                  1
# 1                     15                 29                  1
# 2                     11                 27                  0
# 3                      4                  4                  0
# 4                    135                236                  2
#
#    leisure_count_5000  sport_count_5000  market_count_5000  price_doc
# 0                   0                52                  4    5850000
# 1                  10                66                 14    6000000
# 2                   4                67                 10    5700000
# 3                   0                26                  3   13100000
# 4                  91               195                 14   16331452
#
# [5 rows x 292 columns]
#       id  timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0  30474 2015-07-01     39.0     20.7      2          9         1      1998.0
# 1  30475 2015-07-01     79.2      NaN      8         17         1         0.0
# 2  30476 2015-07-01     40.5     25.1      3          5         2      1960.0
# 3  30477 2015-07-01     62.8     36.0     17         17         1      2016.0
# 4  30478 2015-07-01     40.0     40.0     17         17         1         0.0
#
#    num_room  kitch_sq        ...          cafe_count_5000_price_1500  \
# 0         1       8.9        ...                                   8
# 1         3       1.0        ...                                   4
# 2         2       4.8        ...                                  42
# 3         2      62.8        ...                                   1
# 4         1       1.0        ...                                   5
#
#   cafe_count_5000_price_2500 cafe_count_5000_price_4000  \
# 0                          0                          0
# 1                          1                          1
# 2                         11                          4
# 3                          1                          2
# 4                          1                          1
#
#    cafe_count_5000_price_high  big_church_count_5000  church_count_5000  \
# 0                           0                      1                 10
# 1                           0                      2                 11
# 2                           0                     10                 21
# 3                           0                      0                 10
# 4                           0                      2                 12
#
#    mosque_count_5000  leisure_count_5000  sport_count_5000  market_count_5000
# 0                  1                   0                14                  1
# 1                  0                   1                12                  1
# 2                  0                  10                71                 11
# 3                  0                   0                 2                  0
# 4                  0                   1                11                  1
#
# [5 rows x 291 columns]
#    timestamp  oil_urals  gdp_quart  gdp_quart_growth  cpi  ppi  gdp_deflator  \
# 0 2010-01-01       76.1        NaN               NaN  NaN  NaN           NaN
# 1 2010-01-02       76.1        NaN               NaN  NaN  NaN           NaN
# 2 2010-01-03       76.1        NaN               NaN  NaN  NaN           NaN
# 3 2010-01-04       76.1        NaN               NaN  NaN  NaN           NaN
# 4 2010-01-05       76.1        NaN               NaN  NaN  NaN           NaN
#
#    balance_trade  balance_trade_growth  usdrub         ...          \
# 0            NaN                   NaN     NaN         ...
# 1            NaN                   NaN     NaN         ...
# 2            NaN                   NaN     NaN         ...
# 3            NaN                   NaN  29.905         ...
# 4            NaN                   NaN  29.836         ...
#
#    provision_retail_space_modern_sqm  turnover_catering_per_cap  \
# 0                              690.0                     6221.0
# 1                              690.0                     6221.0
# 2                              690.0                     6221.0
# 3                              690.0                     6221.0
# 4                              690.0                     6221.0
#
#    theaters_viewers_per_1000_cap  seats_theather_rfmin_per_100000_cap  \
# 0                          527.0                                 0.41
# 1                          527.0                                 0.41
# 2                          527.0                                 0.41
# 3                          527.0                                 0.41
# 4                          527.0                                 0.41
#
#    museum_visitis_per_100_cap  bandwidth_sports  population_reg_sports_share  \
# 0                       993.0               NaN                          NaN
# 1                       993.0               NaN                          NaN
# 2                       993.0               NaN                          NaN
# 3                       993.0               NaN                          NaN
# 4                       993.0               NaN                          NaN
#
#    students_reg_sports_share  apartment_build  apartment_fund_sqm
# 0                      63.03          22825.0                 NaN
# 1                      63.03          22825.0                 NaN
# 2                      63.03          22825.0                 NaN
# 3                      63.03          22825.0                 NaN
# 4                      63.03          22825.0                 NaN
#
# [5 rows x 100 columns]

# %%
display(train_df.shape)
display(train_df.describe())
display(test_df.shape)
display(test_df.describe())
display(macro_df.shape)
display(macro_df.describe())
# Out:
# (30471, 292)
#                  id       full_sq       life_sq         floor     max_floor  \
# count  30471.000000  30471.000000  24088.000000  30304.000000  20899.000000
# mean   15237.917397     54.214269     34.403271      7.670803     12.558974
# std     8796.501536     38.031487     52.285733      5.319989      6.756550
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%     7620.500000     38.000000     20.000000      3.000000      9.000000
# 50%    15238.000000     49.000000     30.000000      6.500000     12.000000
# 75%    22855.500000     63.000000     43.000000     11.000000     17.000000
# max    30473.000000   5326.000000   7478.000000     77.000000    117.000000
#
#            material    build_year      num_room      kitch_sq         state  \
# count  20899.000000  1.686600e+04  20899.000000  20899.000000  16912.000000
# mean       1.827121  3.068057e+03      1.909804      6.399301      2.107025
# std        1.481154  1.543878e+05      0.851805     28.265979      0.880148
# min        1.000000  0.000000e+00      0.000000      0.000000      1.000000
# 25%        1.000000  1.967000e+03      1.000000      1.000000      1.000000
# 50%        1.000000  1.979000e+03      2.000000      6.000000      2.000000
# 75%        2.000000  2.005000e+03      2.000000      9.000000      3.000000
# max        6.000000  2.005201e+07     19.000000   2014.000000     33.000000
#
#            ...       cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# count      ...                     30471.000000                30471.000000
# mean       ...                        32.058318                   10.783860
# std        ...                        73.465611                   28.385679
# min        ...                         0.000000                    0.000000
# 25%        ...                         2.000000                    1.000000
# 50%        ...                         8.000000                    2.000000
# 75%        ...                        21.000000                    5.000000
# max        ...                       377.000000                  147.000000
#
#        cafe_count_5000_price_high  big_church_count_5000  church_count_5000  \
# count                30471.000000           30471.000000       30471.000000
# mean                     1.771783              15.045552          30.251518
# std                      5.418807              29.118668          47.347938
# min                      0.000000               0.000000           0.000000
# 25%                      0.000000               2.000000           9.000000
# 50%                      0.000000               7.000000          16.000000
# 75%                      1.000000              12.000000          28.000000
# max                     30.000000             151.000000         250.000000
#
#        mosque_count_5000  leisure_count_5000  sport_count_5000  \
# count       30471.000000        30471.000000      30471.000000
# mean            0.442421            8.648814         52.796593
# std             0.609269           20.580741         46.292660
# min             0.000000            0.000000          0.000000
# 25%             0.000000            0.000000         11.000000
# 50%             0.000000            2.000000         48.000000
# 75%             1.000000            7.000000         76.000000
# max             2.000000          106.000000        218.000000
#
#        market_count_5000     price_doc
# count       30471.000000  3.047100e+04
# mean            5.987070  7.123035e+06
# std             4.889219  4.780111e+06
# min             0.000000  1.000000e+05
# 25%             1.000000  4.740002e+06
# 50%             5.000000  6.274411e+06
# 75%            10.000000  8.300000e+06
# max            21.000000  1.111111e+08
#
# [8 rows x 276 columns]
# (7662, 291)
#                  id      full_sq      life_sq        floor    max_floor  \
# count   7662.000000  7662.000000  6486.000000  7662.000000  7662.000000
# mean   34304.500000    53.701164    32.660037     7.652571    12.591099
# std     2211.973214    20.104320    22.737855     5.099418     6.659291
# min    30474.000000     0.000000     0.000000     1.000000     0.000000
# 25%    32389.250000    39.200000    19.900000     4.000000     9.000000
# 50%    34304.500000    50.410000    30.400000     7.000000    14.000000
# 75%    36219.750000    63.300000    41.800000    11.000000    17.000000
# max    38135.000000   403.000000   869.000000    41.000000    48.000000
#
#           material   build_year     num_room     kitch_sq        state  \
# count  7662.000000  6613.000000  7662.000000  7662.000000  6968.000000
# mean      1.854216  1820.888099     1.876403     6.938662     1.985792
# std       1.517171   552.993964     0.835665    25.579688     0.820086
# min       1.000000     0.000000     1.000000     0.000000     1.000000
# 25%       1.000000  1966.000000     1.000000     1.000000     1.000000
# 50%       1.000000  1982.000000     2.000000     7.000000     2.000000
# 75%       2.000000  2011.000000     2.000000     9.500000     3.000000
# max       6.000000  2019.000000    19.000000  1968.000000     4.000000
#
#              ...          cafe_count_5000_price_1500  \
# count        ...                         7662.000000
# mean         ...                           69.532890
# std          ...                          129.533773
# min          ...                            0.000000
# 25%          ...                            7.000000
# 50%          ...                           27.000000
# 75%          ...                           54.000000
# max          ...                          643.000000
#
#        cafe_count_5000_price_2500  cafe_count_5000_price_4000  \
# count                 7662.000000                 7662.000000
# mean                    35.777865                   12.152310
# std                     76.524992                   29.590097
# min                      0.000000                    0.000000
# 25%                      2.000000                    1.000000
# 50%                     10.000000                    2.000000
# 75%                     25.000000                    5.000000
# max                    374.000000                  145.000000
#
#        cafe_count_5000_price_high  big_church_count_5000  church_count_5000  \
# count                 7662.000000            7662.000000        7662.000000
# mean                     2.007439              16.749152          33.109371
# std                      5.664540              30.706709          49.734993
# min                      0.000000               0.000000           0.000000
# 25%                      0.000000               3.000000          10.000000
# 50%                      0.000000               7.000000          17.000000
# 75%                      1.000000              13.000000          29.000000
# max                     29.000000             150.000000         249.000000
#
#        mosque_count_5000  leisure_count_5000  sport_count_5000  \
# count        7662.000000         7662.000000       7662.000000
# mean            0.412425            9.639650         56.235839
# std             0.608938           21.499687         47.632547
# min             0.000000            0.000000          0.000000
# 25%             0.000000            0.000000         12.000000
# 50%             0.000000            2.000000         51.000000
# 75%             1.000000            7.000000         79.000000
# max             2.000000          105.000000        212.000000
#
#        market_count_5000
# count        7662.000000
# mean            6.330723
# std             4.956223
# min             0.000000
# 25%             2.000000
# 50%             5.000000
# 75%            11.000000
# max            21.000000
#
# [8 rows x 275 columns]
# (2484, 100)
#          oil_urals     gdp_quart  gdp_quart_growth          cpi          ppi  \
# count  2484.000000   2394.000000       2394.000000  2453.000000  2453.000000
# mean     86.467157  16993.230075          1.523726   407.808398   480.216347
# std      27.528709   3187.074480          2.875659    65.895969    70.286366
# min      29.112500   9995.800000         -4.500000   315.100000   337.200000
# 25%      61.283300  14925.000000          0.400000   354.000000   438.400000
# 50%     101.416500  17442.100000          1.300000   393.000000   473.500000
# 75%     109.310000  19284.100000          4.100000   469.400000   520.700000
# max     122.520000  22016.100000          5.200000   531.000000   606.100000
#
#        gdp_deflator  balance_trade  balance_trade_growth       usdrub  \
# count   2119.000000    2453.000000           2394.000000  2481.000000
# mean     110.122308      15.344006             16.846742    40.732406
# std       14.818429       3.878104             16.988727    15.006583
# min       86.721000       5.823000             -4.100000    27.276300
# 25%      100.000000      12.785000              7.200000    30.508800
# 50%      108.299000      16.041000             10.500000    32.316500
# 75%      123.661000      18.076000             21.500000    53.752300
# max      133.160000      21.939000             75.800000    82.276400
#
#             eurrub         ...          provision_retail_space_modern_sqm  \
# count  2481.000000         ...                                 730.000000
# mean     50.444801         ...                                 480.500000
# std      13.905912         ...                                 209.643641
# min      37.445400         ...                                 271.000000
# 25%      40.242600         ...                                 271.000000
# 50%      42.862200         ...                                 480.500000
# 75%      61.323700         ...                                 690.000000
# max      90.881500         ...                                 690.000000
#
#        turnover_catering_per_cap  theaters_viewers_per_1000_cap  \
# count                2191.000000                     1461.00000
# mean                 8691.922410                      580.51540
# std                  1668.967502                       37.98811
# min                  6221.000000                      527.00000
# 25%                  6943.000000                      565.00000
# 50%                  8522.000000                      603.00000
# 75%                 10311.000000                      603.00000
# max                 10805.000000                      627.00000
#
#        seats_theather_rfmin_per_100000_cap  museum_visitis_per_100_cap  \
# count                          2191.000000                 1461.000000
# mean                              0.443398                 1245.543463
# std                               0.016061                  162.526951
# min                               0.410000                  993.000000
# 25%                               0.439390                 1240.000000
# 50%                               0.450700                 1309.000000
# 75%                               0.453560                 1309.000000
# max                               0.458880                 1440.000000
#
#        bandwidth_sports  population_reg_sports_share  \
# count       1826.000000                   1461.00000
# mean      349902.577766                     25.06859
# std        72146.453110                      2.44944
# min       269768.000000                     22.37000
# 25%       288177.000000                     23.01000
# 50%       329348.000000                     23.01000
# 75%       398451.000000                     26.70000
# max       463938.000000                     28.20000
#
#        students_reg_sports_share  apartment_build  apartment_fund_sqm
# count                1461.000000      1826.000000         1826.000000
# mean                   67.800034     36282.434830       230615.059255
# std                     5.168602     10761.669111         2944.879242
# min                    63.030000     22825.000000       226047.300000
# 25%                    64.120000     23587.000000       229294.800000
# 50%                    67.850000     42551.000000       230310.000000
# 75%                    67.850000     46080.000000       232840.200000
# max                    76.200000     46352.000000       234576.900000
#
# [8 rows x 96 columns]

# %% [markdown]
# ### A quick glance already tells us that there are a lot of missing values in the data. Further one can see that all three datasets have the common feature **timestamp**, which we can use to merge the dataframes.
#
# <p>I will merge the test and train datasets with the macro dataset. Therefore I will merge those dataframes based on their timestamp:<p>
# <img src="http://blog.codinghorror.com/content/images/uploads/2007/10/6a0120a85dcdae970b01287770273e970c-pi.png" width="200", align = "left", alt = "blog.codinghorror.com">
# <p></p>
# <p>Here **A** represents the train and test data while **B** is the macro data</p>

# %% [markdown]
# <p>Generation of different dataframes<p>
# <ol>
#     <li><p>**df_no_macro**: train and test but w/o macro</p></li>
#     <li><p>**df_complete**: train and test w/ macro</p></li>
#     <li><p>**df_imputed**: df with imputed values -> base for df_pca and df_ppca</p></li>
#     <li><p>**df_pca**: complete dataset w/ pca</p></li>
#     <li><p>**df_ppca**: partial pca on df_complete - df_direct</p></li>
# </ol>
#
# <p>What to do?</p>
# <ol>
#     <li><p>Generate df_all</p></li>
#     <li><p>Make imputations and feature engineering. (different df)</p></li>
#     <li><p>train model</p></li>
# </ol>

# %%
id_test = test_df["id"]
id_train = train_df["id"]
#train_df.loc[train_df.full_sq == 0, 'full_sq'] = 50
#train_df = train_df[train_df.price_doc/train_df.full_sq <= 600000]
#train_df = train_df[train_df.price_doc/train_df.full_sq >= 10000]
y_log = np.log1p(train_df["price_doc"])

train_df.drop(["id", "price_doc"], axis=1, inplace=True)
test_df.drop("id", axis=1, inplace=True)
#Taken from https://www.kaggle.com/robertoruiz/dealing-with-multicollinearity/notebook/notebook
macro_df = macro_df[["timestamp","balance_trade","balance_trade_growth","eurrub","average_provision_of_build_contract",
                     "micex_rgbi_tr","micex_cbi_tr","deposits_rate","mortgage_value","mortgage_rate","income_per_cap",
                     "museum_visitis_per_100_cap","apartment_build"]]

# %%
df_no_macro = pd.concat([train_df, test_df])
df_complete = pd.merge(left = df_no_macro, right = macro_df, how = "left", on = "timestamp")

# %% [markdown]
# ### Ok now that we have merged the dataframes, lets look for missing values and the data's distribution
# <p>I want to look at ***how many columns have missing values*** and what features have ***the most missing values***.

# %%
null_values = pd.DataFrame(sorted(df_complete.isnull().sum()))
plt.hist(null_values, bins=25);

no_features = df_complete.shape[1]
no_missing = df_complete.shape[1] - df_complete.dropna(axis=1).shape[1]

print("From {} features, {} having missing values. Thats {}% of them.".format(
        no_features, no_missing, round(no_missing/no_features*100),2))

msn.matrix(df_complete, sort="ascending")
# Out:
# From 302 features, 56 having missing values. Thats 19% of them.

# %% [markdown]
# <p>Looking at the histogram we can see that there are some features with show very high missing value counts. We should investigate this more.</p>
# <p>We can look how much percent of the values are actually missing and what features are those.</p>

# %%
total = df_complete.isnull().sum().sort_values(ascending=False)
perc = (df_complete.isnull().sum()/df_complete.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, perc], axis=1, keys=['Total Missing', 'Percent'])
#print(missing_data["Percent"][missing_data["Percent"]>0][:25])
#plt.hist(missing_data["Percent"][missing_data["Percent"]>0], bins=25);
"""
#grouping features based on missing values
mt50 = missing_data["Percent"][missing_data["Percent"]>0.5]
mt25 = missing_data["Percent"][(missing_data["Percent"]>0.25) & (missing_data["Percent"]<0.5)]
mt10 = missing_data["Percent"][(missing_data["Percent"]>0.1) & (missing_data["Percent"]<0.25)]
mt5 = missing_data["Percent"][(missing_data["Percent"]>0.05) & (missing_data["Percent"]<0.1)]
lt5 = missing_data["Percent"][missing_data["Percent"]<0.05] 

print("Features with more than 50% missing values: {}".format(len(mt50)))
print("Those are: ")
for i,ind in enumerate(mt50.index):
    print("{} with {}% missing.".format(ind, round(mt50[i]*100,2)))
print("\n")
print("Features with more than 25% missing values: {}".format(len(mt25)))
print("Those are: ")
for i,ind in enumerate(mt25.index):
    print("{} with {}% missing.".format(ind, round(mt25[i]*100,2)))
print("\n")
print("Features with more than 10% missing values: {}".format(len(mt10)))
for i,ind in enumerate(mt10.index):
    print("{} with {}% missing.".format(ind, round(mt10[i]*100,2)))
print("\n")
print("Features with more than 5% missing values: {}".format(len(mt5)))
print("Features with less than 5% missing values: {}".format(len(lt5)))
""";

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation='90')
sns.barplot(x=perc[perc > 0].index, y=perc[perc > 0]*100);
plt.title("Missing Values", fontsize=18)
plt.ylabel("%")
plt.ylim(0,100);
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):

# %% [markdown]
# <p>Ok, lets quickly look at the test.csv and if more or less the same features show high missing value counts</p>

# %% [markdown]
# <p>So there are some features with a lot of missing values, which are probably important for the house price.</p>
# <p>When we look at the features we have basically 3 types of features:</p>
# <ul>
#     <li><p>Features of the house itself (e.g. *num_room*).</P></li>
#     <li><p>Features of the neighbourhood (e.g. *oil_chemistry_*).</P></li>
#     <li><p>Features of Russia's economy (e.g. *gdp_annual*).</P></li>
# </ul>
# <p>Features of the house itself are probably most important for price predictions, therefore I will carefully look at those. Those features are:</p>
# <ul>
#     <li><p>**price_doc**: This is our target variable, the housing price in rubel.</P></li>
#     <li><p>**id**: This is the id of the house. This is not important and we can drop it.</P></li>
#     <li><p>**full_sq**: This are the total m² of the house.</P></li>
#     <li><p>**life_sq**: This are the living room m².</P></li>
#     <li><p>**floor**: This is only for apartments and shows the floor on which the apartment is.</P></li>
#     <li><p>**max_floor**: The max floor of the building the apartment is in.</P></li>
#     <li><p>**material**: The material of the walls:
#     <ol>
#         <li><p>panel</p></li>
#         <li><p>brick</p></li>
#         <li><p>wood</p></li>
#         <li><p>mass concrete</p></li>
#         <li><p>breezeblock</p></li>
#         <li><p>mass concrete plus brick</p></li>
#     </ol><p></p>
#     <li><p>**build_year**: The year in which the house was (will be) build. (*This can also be in the future*)</P></li>
#     <li><p>**kitch_sq**: This are the kitchen m².</P></li>
#     <li><p>**num_room**: number of living rooms</P></li>
#     <li><p>**state**: The state in which the house is (4 best, 1 worst).</P></li>
#     <li><p>**product_type**: owner-occupier purchase or investment.</P></li>
#     <li><p>**sub_area**: name of the district.</P></li>
# </ul>
# <p>Let's have a closer look at those. So we have continous numeric features:</p>
# <ul><li><p>price_doc, full_sq, life_sq, kitch_sq</p></li></ul>
# <p>some discrete numeric features:</p>
# <ul><li><p>floor, max_floor, build_year, num_room</p></li></ul>
# <p>and some categorical</p>
# <ul><li><p>material, product_type, sub_area and state</p></li></ul>
#
# <p>Lets explore them</p>

# %% [markdown]
# ### Continous Feature Cleaning

# %%
cont = ["full_sq", "life_sq","kitch_sq"]
disc = ["floor", "max_floor", "build_year", "num_room"]
cat = ["material", "state", "product_type"]

# %%
plt.figure(figsize=(20,10))
plt.subplot(321)
plt.title("Regression plot of m²-features")
sns.regplot(df_complete["full_sq"], df_complete["life_sq"])
plt.subplot(322)
plt.title("Regression plot of m²-features - zoom")
plt.xlim(0,600)
plt.ylim(0,500)
sns.regplot(df_complete["full_sq"], df_complete["life_sq"])
plt.subplot(323)
sns.regplot(df_complete["full_sq"], df_complete["kitch_sq"])
plt.subplot(324)
plt.xlim(0,300)
plt.ylim(0,200)
sns.regplot(df_complete["full_sq"], df_complete["kitch_sq"])
plt.subplot(325)
sns.regplot(df_complete["life_sq"], df_complete["kitch_sq"])
plt.subplot(326)
plt.xlim(0,300)
plt.ylim(0,200)
sns.regplot(df_complete["life_sq"], df_complete["kitch_sq"])

display(df_complete[cont].describe());
# Out:
#             full_sq       life_sq      kitch_sq
# count  38133.000000  30574.000000  28561.000000
# mean      54.111172     34.033460      6.543995
# std       35.171162     47.581529     27.571630
# min        0.000000      0.000000      0.000000
# 25%       38.900000     20.000000      1.000000
# 50%       50.000000     30.000000      6.000000
# 75%       63.000000     43.000000      9.000000
# max     5326.000000   7478.000000   2014.000000

# %% [markdown]
# <p>A quick plot reveals some severe outliers, which we would like to reove.</p>
# <p>When we look at the plots we can observe the following:</p>
# <ol>
#     <li><p>For some values ***life_sq > full_sq***.</p></li>
#     <li><p>For some values ***kitch_sq > full_sq***.</p></li>
#     <li><p>All three features show some outliers.</p></li>
#     <li><p>The ratio of ***full_sq : life_sq*** seems to be terribly off for some cases.</p></li>
# </ol>
# <p>When we look at the features full_sq, life_sq and kitch_sq we can set up following rules: </p>
# <ol>
#     <li><p>full_sq >= life_sq > kitch_sq</p></li>
#     <li><p>full_sq > 5 & life_sq > 5</p></li>
#     <li><p>full_sq < 500</p></li>
#     <li><p>life_sq < 500</p></li>
#     <li><p>(kitch_sq >= 1 & full_sq < 15) or kitch_sq > 1</p></li>
#     <li><p>life_sq/full_sq < 0.4</p></li>
# </ol>
# <p>I chose a cutoff of 5 m² since there are micro appartments with comparable sizes.</p>
# <p>We will look at violation in detail and decide what to do.</p>

# %%
for i in range(len(df_complete)):
    if df_complete.loc[i, "full_sq"] < 5 or df_complete.loc[i, "full_sq"] > 300:
        df_complete.loc[i, "full_sq"] = np.NaN
    if df_complete.loc[i, "life_sq"] > df_complete.loc[i, "full_sq"] or df_complete.loc[i, "life_sq"] < 5 or\
    df_complete.loc[i, "life_sq"] > 300:
        df_complete.loc[i, "life_sq"] = np.NaN
    if df_complete.loc[i, "kitch_sq"] >= df_complete.loc[i, "full_sq"] or\
    df_complete.loc[i, "kitch_sq"] >= df_complete.loc[i, "life_sq"] and df_complete.loc[i, "life_sq"] > 5 or\
    df_complete.loc[i, "kitch_sq"] <= 1 and df_complete.loc[i, "full_sq"] <= 15 or\
    df_complete.loc[i, "kitch_sq"] < 2:
        df_complete.loc[i, "kitch_sq"] = np.NaN
    if df_complete.loc[i, "full_sq"] > 0 and df_complete.loc[i, "life_sq"] > 0:
        if df_complete.loc[i, "life_sq"]/df_complete.loc[i, "full_sq"] < 0.4:
            df_complete.loc[i, "life_sq"] = np.NaN

# %% [markdown]
# <p>Ok so this should do it for the continous numeric features. However, before we move on lets visualize these again in order to see if the plots are looking better.</p>

# %%
plt.figure(figsize=(20,10))
plt.subplot(321)
sns.regplot(df_complete["full_sq"], df_complete["life_sq"]);
plt.subplot(322)
plt.xlim(0,600)
plt.ylim(0,500)
sns.regplot(df_complete["full_sq"], df_complete["life_sq"]);
plt.subplot(323)
sns.regplot(df_complete["full_sq"], df_complete["kitch_sq"]);
plt.subplot(324)
plt.xlim(0,300)
plt.ylim(0,100)
sns.regplot(df_complete["full_sq"], df_complete["kitch_sq"]);
plt.subplot(325)
sns.regplot(df_complete["life_sq"], df_complete["kitch_sq"]);
plt.subplot(326)
plt.xlim(0,300)
plt.ylim(0,100)
sns.regplot(df_complete["life_sq"], df_complete["kitch_sq"]);

display(df_complete[cont].describe());
# Out:
#             full_sq       life_sq      kitch_sq
# count  38088.000000  29357.000000  20078.000000
# mean      53.850841     34.602912      8.162696
# std       20.791096     17.849044      2.748633
# min        5.000000      8.000000      2.000000
# 25%       38.900000     20.000000      6.000000
# 50%       50.000000     30.000000      8.000000
# 75%       63.000000     43.000000     10.000000
# max      291.000000    232.700000     57.000000

# %% [markdown]
# ### Discrete Feature Cleaning
# <p>So after we dealt with the continous numeric features lets have a look at the discrete features.n Again lets start with some basic exploration and visualization.</p>

# %%
df_complete[disc].describe()
# Out:
#               floor     max_floor    build_year      num_room
# count  37966.000000  28561.000000  2.347900e+04  28561.000000
# mean       7.667123     12.567592  2.716785e+03      1.900844
# std        5.276156      6.730496  1.308521e+05      0.847620
# min        0.000000      0.000000  0.000000e+00      0.000000
# 25%        3.000000      9.000000  1.966000e+03      1.000000
# 50%        7.000000     12.000000  1.980000e+03      2.000000
# 75%       11.000000     17.000000  2.006000e+03      2.000000
# max       77.000000    117.000000  2.005201e+07     19.000000

# %%
plt.figure()
plt.subplot(121)
plt.title("Floor")
plt.hist(df_complete["floor"].dropna(), bins=100, alpha = 0.75);
plt.hist(df_complete["max_floor"].dropna(), bins=100, alpha = 0.5);
plt.subplot(122)
plt.title("Room number")
plt.hist(df_complete["num_room"].dropna(), bins=10);
plt.figure()
plt.title("Year build")
plt.hist(sorted(df_complete["build_year"].dropna())[1000:-50], bins=80);

# %% [markdown]
# ### Cleaning the discrete values
# <p>Ok so there are some things to do:</p>
# <ul><li><p>**Floors**</p>
#         <ol>
#             <li><p>The Oko1 tower is Moscow's highest skyscraper with 85 floors.
#             This is the max value for floor and max_floor.</p></li>
#             <li><p>The floor must not be larger than the max_floor value.</p>
#             *After lookig at the values in detail it seems not likely that values were just swapped.*</li>
#         </ol>
#     </li><p></p>
#     <li><p>**num_room**</p>
#         <ol>
#             <li><p>The room number should be larger than 0.</p></li>
#             <li><p>We can also compare the room_num with life_sq. The average room size shouldn't be smaller than 4 m².</p></li>
#         </ol>
#     </li><p></p>
#     <li><p>**build_year**</p>
#         <ol>
#             <li><p>There are two outlier which will be manually corrected.</p></li>
#             <li><p>Values smaller than 1900 will be replaced with NaN.</p></li>
#         </ol>
#     </li>
# </ul>

# %%
print(df_complete.loc[10089, "build_year"])
print(df_complete.loc[15220, "build_year"])
df_complete.loc[10089, "build_year"] = 2007
df_complete.loc[15220, "build_year"] = 1965

for i in range(len(df_complete)):
    if df_complete.loc[i, "floor"] > 85:
        df_complete.loc[i, "floor"] = np.NaN
    if df_complete.loc[i, "max_floor"] > 85:
        df_complete.loc[i, "max_floor"] = np.NaN
    if df_complete.loc[i, "max_floor"] < df_complete.loc[i, "floor"]:
        df_complete.loc[i, "max_floor"] = np.NaN
    
    if df_complete.loc[i, "build_year"] < 1500:
        df_complete.loc[i, "build_year"] = np.NaN
    if df_complete.loc[i, "build_year"] > 2020:
        df_complete.loc[i, "build_year"] =np.NaN
        
    if df_complete.loc[i, "num_room"] == 0:
        df_complete.loc[i, "num_room"] = np.NaN
    if df_complete.loc[i, "life_sq"] > 0 and df_complete.loc[i, "num_room"] > 0:    
        if df_complete.loc[i, "life_sq"]/df_complete.loc[i, "num_room"] < 4:
            df_complete.loc[i, "num_room"] = np.NaN
# Out:
# 20052009.0
# 4965.0

# %%
display(df_complete[disc].describe())

plt.figure(figsize=(20,5))
plt.subplot(121)
plt.title("Floor")
plt.hist(df_complete["floor"].dropna(), bins=100, alpha = 0.75);
plt.hist(df_complete["max_floor"].dropna(), bins=100, alpha = 0.5);
plt.subplot(122)
plt.title("Room number")
plt.hist(df_complete["num_room"].dropna(), bins=10);
plt.figure(figsize=(20,5))
plt.title("Year build")
plt.xlim(1900,2020)
plt.xticks(rotation=90)
sns.countplot(df_complete["build_year"])
# Out:
#               floor     max_floor    build_year      num_room
# count  37966.000000  26421.000000  22018.000000  28541.000000
# mean       7.667123     13.499716   1986.252066      1.899338
# std        5.276156      5.962326     21.297968      0.826756
# min        0.000000      0.000000   1691.000000      1.000000
# 25%        3.000000      9.000000   1969.000000      1.000000
# 50%        7.000000     14.000000   1983.000000      2.000000
# 75%       11.000000     17.000000   2008.000000      2.000000
# max       77.000000     57.000000   2019.000000      9.000000

# %% [markdown]
# ## Let's add relative floor and average room size as features

# %%
df_complete["rel_floor"] = df_complete["floor"] / df_complete["max_floor"].astype(float)
df_complete["avrg_room"] = df_complete["life_sq"] / df_complete["num_room"].astype(float)

# %% [markdown]
#  ### Categorical Feature Cleaning
#  <p>So we have 4 categorical features that might need some cleaning. We know that there are 6 material types, 4 state types and 2 product types.</p>

# %%
for i in cat:
    display(df_complete[i].value_counts())
# Out:
# 1.0    19438
# 2.0     3951
# 5.0     2048
# 4.0     1963
# 6.0     1159
# 3.0        2
# Name: material, dtype: int64
# 2.0     8506
# 3.0     7703
# 1.0     7121
# 4.0      549
# 33.0       1
# Name: state, dtype: int64
# Investment       24446
# OwnerOccupier    13654
# Name: product_type, dtype: int64

# %%
x = (df_complete["state"][df_complete["state"] == 33].index[0])
df_complete.loc[x, ["state"]] = 3

# %% [markdown]
# # Lets change the timestamp into year month and day ow week and drop timestamp

# %%
df_complete['year'] = df_complete.timestamp.dt.year
df_complete['month'] = df_complete.timestamp.dt.month
df_complete['dow'] = df_complete.timestamp.dt.dayofweek
df_complete.drop(['timestamp'], axis=1, inplace=True)

# %% [markdown]
# #### short summary:
# #### We merged the train, test and macro df into one big dataframe and afterwards we looked at missing values and looked data inconsitencies for important features in detail. Next steps will be to facorize categorical features.
# #### Afterwards in one approach I will try a PCA analysis. Therefore the missing values of the data have to be imputed and the data has to be scaled and normalized.
# #### Then the different models will be trained on the different dataframes using crossvalidation. Here I will have to think of a good pipeline implementation to come up with. Further the data has to be in good shape since this will indeed be a rather time consuming step.

# %%
df_complete_num = df_complete.select_dtypes(exclude = ["object"])
df_complete_obj = df_complete.select_dtypes(include = ["object"]).copy()
df_complete_obj.fillna("NaN", inplace=True)
enc = LabelEncoder()
for obj in df_complete_obj:
        df_complete_obj[obj] = enc.fit_transform(df_complete_obj[obj])

# %%
df_complete_encoded = pd.concat([df_complete_num, df_complete_obj], axis=1)
pos = len(train_df)
df_no_macro = df_complete_encoded.drop(macro_df.columns[1:], axis=1)
df_train1 = df_no_macro[:pos]
df_test1 = df_no_macro[pos:]

df_train2 = df_complete_encoded[:pos]
df_test2 = df_complete_encoded[pos:]

# %% [markdown]
# #### Ok so at this point we have a df_train a df_test and y_log, this dfs can be used to train boosting algos which are insentive to missing values and do not rely on scaled or normalized data. I will try to run a xgboost a light general boost and a random forest ensemble on this datasets.
# #### I also will impute missing values, scale and normlize the data and perfom pca. Afterwards I will run besides the upper algos additionaly a ridge and lasso regression on the dfs.
# #### The best performing untuned model will then be subjected to hyperparameter tuning

# %% [markdown]
# # Some exploration of the cleaned data

# %% [markdown]
# ### Correlation matrix

# %%
#cor = test_df.select_dtypes(exclude = ["object"]).corr()

# %%
#plt.figure(figsize=(20,20))
#sns.clustermap(cor, square=True, linewidth=1, annot= False, cmap=cmap);
#sns.heatmap(cor)
#plt.xticks(rotation=45);
#plt.yticks(rotation=0);

#cholesky = np.linalg.cholesky(cor)
#for i in cholesky:
#    print(i)

# %% [markdown]
# ### Categorical features
# <p>***Material***</p>
# <p>When we look at the categorical features we can see that the material does not show to high correlation with the target variable. Maybe material 2 shows slightly higher, while material 5 slightly lower prices.<p>
# <p>***State***</p>
# <p>when we look at the state we can see a increase of the target variable with higher state.</p>
# <p>***Product type***</p>
# <p>Product types does not have too much of an influence on the price</p>

# %%
plt.figure(figsize=(20,10))
ax = plt.subplot(311)
plt.title("Price vs Categorical Features\n")
sns.violinplot(x="material", y=y_log, data=df_complete_encoded)
ax.hlines(np.median(y_log),-1,6, linestyle='--', alpha=0.3)
ax = plt.subplot(312)
sns.violinplot(x="state", y=y_log, data=df_complete_encoded)
ax.hlines(np.median(y_log),-1,6, linestyle='--', alpha=0.3)
ax = plt.subplot(313)
sns.violinplot(x="product_type", y=y_log, data=df_complete_encoded)
ax.hlines(np.median(y_log),-1,6, linestyle='--', alpha=0.3)
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):

# %% [markdown]
# # Continous variables
# <p>There are some obvious correlations between those. Lets look at them some more and maybe group them in a new variable, in order to reduce dimensionality.</p>

# %%
plt.figure(figsize=(20,15))
plt.subplot(321)
sns.barplot("num_room", "full_sq", data=df_complete_encoded)
plt.subplot(322)
sns.regplot("num_room", "full_sq", data=df_complete_encoded)
plt.subplot(323)
sns.barplot("num_room", "life_sq", data=df_complete_encoded)
plt.subplot(324)
sns.regplot("num_room", "life_sq", data=df_complete_encoded)
plt.subplot(325)
sns.barplot("num_room", "kitch_sq", data=df_complete_encoded)
plt.subplot(326)
sns.regplot("num_room", "kitch_sq", data=df_complete_encoded)
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):

# %%
plt.figure(figsize=(20,7))
sns.barplot("build_year", y_log, data=df_complete_encoded);
plt.xticks(rotation=90);
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):

# %%
plt.figure(figsize=(20,7))
sns.countplot("build_year", data=df_complete_encoded);
plt.xticks(rotation=90);

# %%
x = pd.concat([df_train1["build_year"], y_log], axis=1)
aver = x.groupby("build_year")[["build_year", "price_doc"]].median()
#recent = df_complete_encoded[["build_year", "price_doc"]][df_complete_encoded["build_year"] > 1850]
sns.regplot("build_year", y_log, data=df_train1, scatter=False, order=2,truncate=True)
plt.plot(aver["build_year"], aver["price_doc"], color ="red")
plt.ylim(14.5,18)
plt.xlim(1850,2025)
# Out:
# (1850, 2025)

# %% [markdown]
# # Ok so lets save the encoded features for later until we have dealt with the numeric ones

# %% [markdown]
# # Feature Reduction
#
# ## I will try to reduce the dimensionality of this data  via PCA

# %% [markdown]
# ## Principal Component Analysis
#
# ### Ok so now lets attempt to reduce the dimensionality of the remaining features by applying a PCA.
# ### For the PCA to yield reliable results we have to do some data transformation first.
#
# <ol>
#     <li><p>Pick all numeric features.</p></li>
#     <li><p>Drop features with too many missing values.</p></li>
#     <li><p>Scale data -> minMaxScaler.</p></li>
#     <li><p>Remove outlier.</p></li>
#     <li><p>PCA</p></li>
# </ol>

# %%
m = df_complete_encoded.isnull().sum()

missing = zip(df_complete_encoded.columns, m)
missing = sorted(missing, key = lambda x: x[1], reverse=True)
missing = pd.DataFrame(missing)
missing.columns = ["Feature", "Missing"]
missing = missing[missing["Missing"] > 0]
missing["perc"] = missing["Missing"]/len(df_complete_encoded)*100

plt.figure(figsize=(20,10))
plt.xticks(rotation = 90)
sns.barplot(missing["Feature"], missing["perc"])
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\seaborn\categorical.py:342: DeprecationWarning: pandas.core.common.is_categorical_dtype is deprecated. import from the public API: pandas.api.types.is_categorical_dtype instead
#   elif is_categorical(y):

# %% [markdown]
# <p>Gonna drop features which show too much missing values. I will choose >20% missing as cutoff. The other features
# are going to be imputed. I will first try a simple median impuation. I will drop features in both datasets.</p>

# %%
missing = missing[missing["perc"] > 5]
df_complete_imputation = df_complete_encoded.drop(missing["Feature"], axis=1, inplace = False)

# %%
df_complete_imputation.fillna(df_complete_imputation.median(), inplace=True);

# %%
#scale data
#scale data
from sklearn.preprocessing import MinMaxScaler, normalize
scaler = MinMaxScaler()
cols = df_complete_imputation.columns
df_complete_imputation = scaler.fit_transform(df_complete_imputation)
df_complete_imputation = normalize(df_complete_imputation)
df_complete_imputation = pd.DataFrame(df_complete_imputation)
df_complete_imputation.columns = cols

# %% [markdown]
# # Check for outlier via IsolationForest

# %%
from sklearn.ensemble import IsolationForest

iso = IsolationForest()
x = iso.fit(df_complete_imputation)
pred = x.predict(df_complete_imputation)

# %%
unique, counts = numpy.unique(pred, return_counts=True)
res = dict(zip(unique, counts))

print(res)
# Out:
# {1: 34319, -1: 3814}

# %%
a = [0 for i in range(len(train_df))]
b = [1 for i in range(len(test_df))]
c = a+b
c = pd.Series(c)

df_complete_imputation["DATA"] = c

# %%
pred_bools = pd.DataFrame(pred, columns=["outlier"])
pred_bools

df_complete_imputation_temp  = pd.concat([df_complete_imputation, pred_bools], axis=1)
df_complete_imputation_train = df_complete_imputation[df_complete_imputation_temp["DATA"] == 0]
df_complete_imputation_test = df_complete_imputation[df_complete_imputation_temp["DATA"] == 1]
df_complete_imputation_train = df_complete_imputation_train[df_complete_imputation_temp["outlier"] == 1]
df_complete_imputation = pd.concat([df_complete_imputation_train, df_complete_imputation_test])

y_bools = pred_bools.iloc[:len(train_df),:]
y_log_imputation = pd.concat([y_log, y_bools], axis=1)
y_log_imputation = y_log_imputation[y_log_imputation["outlier"] == 1]
y_log_imputation.drop("outlier", axis=1, inplace=True)
y_log_imputation = y_log_imputation.values
y_log_imputation = pd.Series(y_log_imputation[:,0])
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
DATA = df_complete_imputation["DATA"]
df_complete_imputation.drop("DATA", axis=1, inplace=True)

# %%
pca = PCA(n_components = 40)
pca = pca.fit(df_complete_imputation)
explained = pca.explained_variance_ratio_
plt.figure()
plt.plot(range(40), np.cumsum(explained), 'o-', color='purple')
plt.title("Explained Variance/Dimension")
plt.xlabel("No. of dimensions")
plt.ylabel("%Variance explained")

# %%
import heapq
plt.figure()
plt.step(range(40), np.cumsum(explained))
plt.xticks(range(40));
dimensions = pca.components_[:3]
plt.figure()
ind = []
for i, dim in enumerate(dimensions):
    plt.subplot(1,3,i+1)
    plt.bar(range(len(df_complete_imputation.columns)), dim)
    ind.append(np.argpartition(dim, -15)[-15:])

# %%
for i in ind:
    print(df_complete_imputation.columns[i])
# Out:
# Index(['kremlin_km', 'zd_vokzaly_avto_km', 'sadovoe_km', 'ttk_km',
#        'bulvar_ring_km', 'railroad_station_avto_km', 'green_part_3000',
#        'ID_railroad_station_avto', 'oil_chemistry_km', 'sub_area',
#        'ID_bus_terminal', 'detention_facility_km', 'green_zone_part',
#        'ID_big_road1', 'product_type'],
#       dtype='object')
# Index(['prom_part_2000', 'office_sqm_5000', 'ID_railroad_terminal',
#        'market_count_3000', 'sport_count_3000', 'trc_count_5000',
#        'indust_part', 'prom_part_3000', 'trc_sqm_5000', 'ecology',
#        'radiation_raion', 'prom_part_5000', 'sport_count_5000',
#        'mosque_count_5000', 'market_count_5000'],
#       dtype='object')
# Index(['green_zone_km', 'product_type', 'preschool_education_centers_raion',
#        'month', 'prom_part_1000', 'incineration_raion',
#        'ID_railroad_station_walk', 'ID_railroad_station_avto', 'balance_trade',
#        'prom_part_2000', 'micex_rgbi_tr', 'prom_part_3000', 'indust_part',
#        'ID_bus_terminal', 'prom_part_1500'],
#       dtype='object')

# %%
df_pca = pca.transform(df_complete_imputation)
df_pca = pd.DataFrame(df_pca)
df_pca.columns = ["PC" + str(i+1) for i in range(len(df_pca.columns))]

# %% [markdown]
# # For partial PCA we will first determine the 10 most important features. Those will be excluded in PCA

# %%
y = y_log
X = df_train2
#X = X[X.columns[X.dtypes!="object"]]

xgb_params = {
    'eta': 0.05,
    'max_depth': 8,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

dtrain = xgb.DMatrix(X, y, feature_names=X.columns.values)
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=100)

#plot the important features #
fig, ax = plt.subplots(figsize=(12,18))
xgb.plot_importance(model, max_num_features=25, height=0.8, ax=ax)
plt.show()

# %%
import operator
x = model.get_score(importance_type='weight')
sorted_x = sorted(x.items(), key=operator.itemgetter(1), reverse=True)
imp_features = [i[0] for i in sorted_x[:10]]

# %%
df_ppca_main = df_complete_encoded[imp_features]

#pred_bools = pd.DataFrame(pred, columns=["outlier"])
#df_ppca_main  = pd.concat([df_ppca_main, pred_bools], axis=1)
#df_ppca_main = df_ppca_main[df_ppca_main["outlier"] == 1]
#df_ppca_main.drop("outlier", axis=1, inplace=True)

df_ppca_side = df_complete_imputation.copy()
for feature in df_ppca_main.columns:
    try:
        df_ppca_side.drop(feature, axis=1, inplace=True)
    except:
        print("{} has already been dropped.".format(feature))
# Out:
# life_sq has already been dropped.
# build_year has already been dropped.
# max_floor has already been dropped.

# %%
ppca = PCA(n_components = 60)
ppca = ppca.fit(df_ppca_side)
explained = ppca.explained_variance_ratio_
cols = ["PC" + str(i+1) for i in range(60)]
features = df_ppca_side.columns
df_ppca_side = ppca.transform(df_ppca_side)
df_ppca_side = pd.DataFrame(df_ppca_side)
df_ppca_side.columns = cols

# %%
import heapq
plt.figure(figsize(20,5))
plt.step(range(1,61), np.cumsum(explained))
plt.xticks(range(1,61));
dimensions = ppca.components_[:3]
plt.figure(figsize(20,5))
ind = []
for i, dim in enumerate(dimensions):
    plt.subplot(1,3,i+1)
    plt.bar(range(len(dim)), dim)
    ind.append(np.argpartition(dim, -15)[-15:])

# %%
for i in ind:
    print(features[i])
# Out:
# Index(['kremlin_km', 'zd_vokzaly_avto_km', 'sadovoe_km', 'ttk_km',
#        'bulvar_ring_km', 'railroad_station_avto_km', 'oil_chemistry_km',
#        'sub_area', 'ID_bus_terminal', 'detention_facility_km',
#        'green_part_3000', 'ID_railroad_station_avto', 'ID_big_road1',
#        'green_zone_part', 'product_type'],
#       dtype='object')
# Index(['market_count_3000', 'prom_part_2000', 'ID_railroad_terminal',
#        'office_sqm_5000', 'sport_count_3000', 'trc_count_5000', 'indust_part',
#        'prom_part_3000', 'trc_sqm_5000', 'ecology', 'radiation_raion',
#        'prom_part_5000', 'market_count_5000', 'mosque_count_5000',
#        'sport_count_5000'],
#       dtype='object')
# Index(['additional_education_raion', 'green_zone_km',
#        'school_education_centers_raion', 'ID_railroad_station_avto',
#        'incineration_raion', 'ID_railroad_station_walk',
#        'preschool_education_centers_raion', 'product_type', 'indust_part',
#        'ID_big_road2', 'ID_bus_terminal', 'prom_part_1500', 'prom_part_2000',
#        'prom_part_3000', 'prom_part_1000'],
#       dtype='object')

# %%
df_ppca_main.reset_index(drop=True, inplace=True)
df_ppca_side.reset_index(drop=True, inplace=True)
df_ppca = pd.concat([df_ppca_main, df_ppca_side.iloc[:,:10]], axis = 1)

# %%
#concat with DATA frame for spliting into test and train

df_complete_imputation = pd.concat([df_complete_imputation, DATA], axis=1)
df_pca = pd.concat([df_pca, DATA], axis=1)
df_ppca = pd.concat([df_ppca, DATA], axis=1)

# %%
df_train3 = df_complete_imputation[df_complete_imputation["DATA"] == 0] 
df_test3 = df_complete_imputation[df_complete_imputation["DATA"] == 1] 
df_train3.drop("DATA", axis=1, inplace=True)
df_test3.drop("DATA", axis=1, inplace=True)

df_train4 = df_pca[df_pca["DATA"] == 0] 
df_test4 = df_pca[df_pca["DATA"] == 1] 
df_train4.drop("DATA", axis=1, inplace=True)
df_test4.drop("DATA", axis=1, inplace=True)

df_train5 = df_ppca[df_ppca["DATA"] == 0] 
df_test5 = df_ppca[df_ppca["DATA"] == 1] 
df_train5.drop("DATA", axis=1, inplace=True)
df_test5.drop("DATA", axis=1, inplace=True)
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Wegee\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Wegee\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Wegee\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Wegee\Anaconda3\lib\site-packages\ipykernel\__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Wegee\Anaconda3\lib\site-packages\ipykernel\__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Before training the algorithm, quickly compare the training and testing data, to see if there are still major differences between those.

# %%
train_means = [np.mean(df_train3[i]) for i in df_train3.columns]
test_means = [np.mean(df_test3[i]) for i in df_test3.columns]
train_std = [np.std(df_train3[i]) for i in df_train3.columns]
test_std = [np.std(df_test3[i]) for i in df_test3.columns]

plt.figure(figsize(5,10))
ax = plt.subplot(121)
plt.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.ylabel("column No.")
plt.xlabel("mean +/- std\ntrain data")
#plt.plot(train_means, range(263), ".b", alpha = 0.5)
plt.xlim(-0.1,0.3)
plt.plot(train_means, range(263), ".b", alpha=0.5)
plt.errorbar(train_means, range(263), xerr=train_std, alpha=0.2)
ax = plt.subplot(122)
plt.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.xlabel("mean +/- std\ntest data")
ax.axes.get_yaxis().set_visible(False)
plt.plot(test_means, range(263), ".r", alpha=0.5)
plt.errorbar(test_means, range(263), xerr=test_std, color="red", alpha=0.2)
# Out:
# <Container object of 3 artists>

# %%
train = [[train_means[i], train_std[i]] for i in range(263)]
train = sorted(train)
test = [[test_means[i], test_std[i]] for i in range(263)]
test = sorted(test)

train_meansx = [i[0] for i in train]
train_stdx = [i[1] for i in train] 
test_meansx = [i[0] for i in test]
test_stdx = [i[1] for i in test] 

plt.figure()
ax = plt.subplot()
ax.axes.get_yaxis().set_visible(False)
plt.xlabel("feature mean +/- std")
plt.grid(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.plot(train_meansx, range(263), ".b", alpha=0.5)
plt.errorbar(train_meansx, range(263), xerr=train_stdx, alpha=0.2)
plt.plot(test_meansx, range(263), ".b", alpha=0.5)
plt.errorbar(test_meansx, range(263), xerr=test_stdx, alpha=0.1, color="red")
# Out:
# <Container object of 3 artists>

# %% [markdown]
# # At this point we've got the following datastructures:
# <ol>
# <li><p>**train_df**&emsp;&emsp;&emsp;	train dataframe w/o id, price_doc</p></li>
# <li><p>**test_df**	&emsp;&emsp;&emsp;			test dataframe w/o id</p></li>
# <li><p>**y_log**	&emsp;&emsp;&emsp;			log1p of price_doc </p></li>
# <p></p>
# <li><p>**df_no_macro**	&emsp;&emsp;&emsp;		train and test w/o macro</p></li>
# <li><p>**df_complete**	&emsp;&emsp;&emsp;	train, test and certain macro features</p></li>
# <li><p>**df_complete_encoded**	&emsp;&emsp;&emsp;	train, test and certain macro features labelencoded</p></li>
# <li><p>**df_complete_imputation**&emsp;&emsp;&emsp;		train,test and certain macro features w/ median impuation</p></li>
# <li><p>**df_pca** 	&emsp;&emsp;&emsp;			full pca on df reduction to 60 dimensions</p></li>
# <li><p>**df_ppca**		&emsp;&emsp;&emsp;		partial pca, leaving out the 10 most important features</p></li>
# <p></p>
# <li><p>**df_train1**	&emsp;&emsp;&emsp;		split of df_no_macro</p></li>
# <li><p>**df_test1**	&emsp;&emsp;&emsp;		split of df_no_macro</p></li>
# <p></p>
# <li><p>**df_train2**&emsp;&emsp;&emsp;			split of df_complete_encoded</p></li>
# <li><p>**df_test2**	&emsp;&emsp;&emsp;		split of df_complete_encoded</p></li>
# <p></p>
# <li><p>**df_train3**&emsp;&emsp;&emsp;			split of df_complete_imputation</p></li>
# <li><p>**df_test3**	&emsp;&emsp;&emsp;		split of df_complete_imputation</p></li>
# <p></p>
# <li><p>**df_train4**&emsp;&emsp;&emsp;			split of df_pca</p></li>
# <li><p>**df_test4**	&emsp;&emsp;&emsp;		split of df_pca</p></li>
# <p></p>
# <li><p>**df_train5**&emsp;&emsp;&emsp;			split of df_ppca</p></li>
# <li><p>**df_test5**&emsp;&emsp;&emsp;			split of df_ppca</p></li>
# </ol>

# %%
dfs = [[df_train1, df_test1], [df_train2, df_test2],[df_train3, df_test3],[df_train_3half, df_test_3half],[df_train4, df_test4],[df_train5, df_test5]]
ylogs = [y_log, y_log, y_log_imputation,y_log_imputation,y_log_imputation,y_log_imputation]
for i, d in enumerate(dfs):
    print("df_train{} shape: {}".format(i+1, d[0].shape))
    print("y_log shape: {}".format(ylogs[i].shape))
    print("df_test{} shape: {}".format(i+1, d[1].shape))
    print()
# Out:
# df_train1 shape: (30471, 294)
# y_log shape: (30471,)
# df_test1 shape: (7662, 294)
#
# df_train2 shape: (30471, 306)
# y_log shape: (30471,)
# df_test2 shape: (7662, 306)
#
# df_train3 shape: (27504, 263)
# y_log shape: (27504,)
# df_test3 shape: (7662, 263)
#
# df_train4 shape: (27552, 296)
# y_log shape: (27504,)
# df_test4 shape: (7662, 296)
#
# df_train5 shape: (27504, 40)
# y_log shape: (27504,)
# df_test5 shape: (7662, 40)
#
# df_train6 shape: (27504, 20)
# y_log shape: (27504,)
# df_test6 shape: (7662, 20)

# %% [markdown]
# # Benchmark

# %%
df_train = [df_train1, df_train2,df_train3, df_train4, df_train5]
ylogs = [y_log, y_log, y_log_imputation,y_log_imputation,y_log_imputation]
rmse_bm = []
for i in range(len(df_train)):
    X_train, X_test, y_train, y_test = train_test_split(df_train[i], ylogs[i], test_size = 0.2, random_state = 1234)
    print("The mean price is: {}".format(np.mean(y_train)))
    y_pred = [np.mean(y_train) for i in range(len(X_test))]
   
    
    print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
    rmse_bm.append(mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# The mean price is: 15.608950655778251
# The rmse of prediction is: 0.6121502702
# The mean price is: 15.608950655778251
# The rmse of prediction is: 0.6121502702
# The mean price is: 15.592988245446705
# The rmse of prediction is: 0.570946564866
# The mean price is: 15.592988245446705
# The rmse of prediction is: 0.570946564866
# The mean price is: 15.592988245446705
# The rmse of prediction is: 0.570946564866

# %% [markdown]
# # First lets train the out of the box algos on the 5 datasets
# # The best performing algo will then be improved :)
#
# # LightGBM

# %%
# load or create your dataset
print('Load data...')
RS = 20170501
df_train = [df_train1, df_train2, df_train3, df_train4, df_train5]
ylogs = [y_log, y_log,y_log_imputation,y_log_imputation,y_log_imputation]
rmse_lgbm = []
elapsed_lgbm = []
for i in range(len(df_train)):

    X_train, X_test, y_train, y_test = train_test_split(df_train[i], ylogs[i], test_size = 0.2, random_state = 1234)

    # create dataset for lightgbm
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

    # specify your configurations as a dict
    params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'regression',
        'metric': 'rmse',
        'num_leaves': 2**5,
        'learning_rate': 0.05,
        'bagging_fraction': 0.95,
        'bagging_freq': 1,
        'bagging_seed': RS,
        'feature_fraction': 0.8,
        'feature_fraction_seed': RS,
        'max_bin': 100,
        'max_depth': 5,
        'verbose': 0
    }

    print('Start training...')
    # train
    start = time.time()
    gbm = lgb.train(params,
                    lgb_train,
                    num_boost_round=1000,
                    valid_sets=lgb_eval,
                    early_stopping_rounds=25)

    #print('Save model...')
    # save model to file
    #gbm.save_model('model.txt')
    elapsed_lgbm.append(time.time()-start)
    print('Start predicting...')
    # predict
    y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
    # eval
    print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
    rmse_lgbm.append(mean_squared_error(y_test, y_pred) ** 0.5)
    #print('Dump model to JSON...')
    # dump model to json (and save to file)
    #model_json = gbm.dump_model()

    #with open('model.json', 'w+') as f:
    #    json.dump(model_json, f, indent=4)


    #print('Feature names:', gbm.feature_name())

    #print('Calculate feature importances...')
    # feature importances
    #print('Feature importances:', list(gbm.feature_importance()))
# Out:
# Load data...
# Start training...
# [1]	valid_0's rmse: 0.60144
# Train until valid scores didn't improve in 25 rounds.
# [2]	valid_0's rmse: 0.591629
# [3]	valid_0's rmse: 0.582617
# [4]	valid_0's rmse: 0.574465
# [5]	valid_0's rmse: 0.568119
# [6]	valid_0's rmse: 0.561072
# [7]	valid_0's rmse: 0.55455
# [8]	valid_0's rmse: 0.548394
# [9]	valid_0's rmse: 0.542756
# [10]	valid_0's rmse: 0.537576
# [11]	valid_0's rmse: 0.532822
# [12]	valid_0's rmse: 0.52842
# [13]	valid_0's rmse: 0.524533
# [14]	valid_0's rmse: 0.520959
# [15]	valid_0's rmse: 0.517581
# [16]	valid_0's rmse: 0.514782
# [17]	valid_0's rmse: 0.511733
# [18]	valid_0's rmse: 0.509064
# [19]	valid_0's rmse: 0.506565
# [20]	valid_0's rmse: 0.504252
# [21]	valid_0's rmse: 0.5023
# [22]	valid_0's rmse: 0.500356
# [23]	valid_0's rmse: 0.498655
# [24]	valid_0's rmse: 0.497156
# [25]	valid_0's rmse: 0.495534
# [26]	valid_0's rmse: 0.494053
# [27]	valid_0's rmse: 0.492692
# [28]	valid_0's rmse: 0.491294
# [29]	valid_0's rmse: 0.490089
# [30]	valid_0's rmse: 0.489133
# [31]	valid_0's rmse: 0.487929
# [32]	valid_0's rmse: 0.487034
# [33]	valid_0's rmse: 0.486059
# [34]	valid_0's rmse: 0.485262
# [35]	valid_0's rmse: 0.484556
# [36]	valid_0's rmse: 0.48386
# [37]	valid_0's rmse: 0.48307
# [38]	valid_0's rmse: 0.482462
# [39]	valid_0's rmse: 0.481818
# [40]	valid_0's rmse: 0.481288
# [41]	valid_0's rmse: 0.480798
# [42]	valid_0's rmse: 0.480205
# [43]	valid_0's rmse: 0.479743
# [44]	valid_0's rmse: 0.479325
# [45]	valid_0's rmse: 0.478889
# [46]	valid_0's rmse: 0.478439
# [47]	valid_0's rmse: 0.478023
# [48]	valid_0's rmse: 0.477538
# [49]	valid_0's rmse: 0.477235
# [50]	valid_0's rmse: 0.476831
# [51]	valid_0's rmse: 0.476475
# [52]	valid_0's rmse: 0.476137
# [53]	valid_0's rmse: 0.475883
# [54]	valid_0's rmse: 0.475659
# [55]	valid_0's rmse: 0.475341
# [56]	valid_0's rmse: 0.475022
# [57]	valid_0's rmse: 0.474811
# [58]	valid_0's rmse: 0.4746
# [59]	valid_0's rmse: 0.47431
# [60]	valid_0's rmse: 0.474094
# [61]	valid_0's rmse: 0.473861
# [62]	valid_0's rmse: 0.473721
# [63]	valid_0's rmse: 0.473546
# [64]	valid_0's rmse: 0.473347
# [65]	valid_0's rmse: 0.473241
# [66]	valid_0's rmse: 0.473091
# [67]	valid_0's rmse: 0.473025
# [68]	valid_0's rmse: 0.472891
# [69]	valid_0's rmse: 0.472734
# [70]	valid_0's rmse: 0.472612
# [71]	valid_0's rmse: 0.472544
# [72]	valid_0's rmse: 0.472466
# [73]	valid_0's rmse: 0.472328
# [74]	valid_0's rmse: 0.472126
# [75]	valid_0's rmse: 0.472019
# [76]	valid_0's rmse: 0.471905
# [77]	valid_0's rmse: 0.471764
# [78]	valid_0's rmse: 0.471722
# [79]	valid_0's rmse: 0.471624
# [80]	valid_0's rmse: 0.471479
# [81]	valid_0's rmse: 0.471325
# [82]	valid_0's rmse: 0.471217
# [83]	valid_0's rmse: 0.471093
# [84]	valid_0's rmse: 0.470962
# [85]	valid_0's rmse: 0.470884
# [86]	valid_0's rmse: 0.47053
# [87]	valid_0's rmse: 0.470472
# [88]	valid_0's rmse: 0.47023
# [89]	valid_0's rmse: 0.470214
# [90]	valid_0's rmse: 0.470154
# [91]	valid_0's rmse: 0.470168
# [92]	valid_0's rmse: 0.470119
# [93]	valid_0's rmse: 0.470101
# [94]	valid_0's rmse: 0.469904
# [95]	valid_0's rmse: 0.469769
# [96]	valid_0's rmse: 0.469472
# [97]	valid_0's rmse: 0.469501
# [98]	valid_0's rmse: 0.469344
# [99]	valid_0's rmse: 0.469053
# [100]	valid_0's rmse: 0.468984
# [101]	valid_0's rmse: 0.468983
# [102]	valid_0's rmse: 0.468957
# [103]	valid_0's rmse: 0.468942
# [104]	valid_0's rmse: 0.468923
# [105]	valid_0's rmse: 0.468855
# [106]	valid_0's rmse: 0.468787
# [107]	valid_0's rmse: 0.468819
# [108]	valid_0's rmse: 0.468754
# [109]	valid_0's rmse: 0.468513
# [110]	valid_0's rmse: 0.468512
# [111]	valid_0's rmse: 0.468501
# [112]	valid_0's rmse: 0.468412
# [113]	valid_0's rmse: 0.468304
# [114]	valid_0's rmse: 0.468257
# [115]	valid_0's rmse: 0.468168
# [116]	valid_0's rmse: 0.468177
# [117]	valid_0's rmse: 0.468198
# [118]	valid_0's rmse: 0.468128
# [119]	valid_0's rmse: 0.468124
# [120]	valid_0's rmse: 0.468084
# [121]	valid_0's rmse: 0.4681
# [122]	valid_0's rmse: 0.468102
# [123]	valid_0's rmse: 0.468068
# [124]	valid_0's rmse: 0.468075
# [125]	valid_0's rmse: 0.467976
# [126]	valid_0's rmse: 0.467984
# [127]	valid_0's rmse: 0.467889
# [128]	valid_0's rmse: 0.467853
# [129]	valid_0's rmse: 0.467807
# [130]	valid_0's rmse: 0.467707
# [131]	valid_0's rmse: 0.46774
# [132]	valid_0's rmse: 0.467778
# [133]	valid_0's rmse: 0.467715
# [134]	valid_0's rmse: 0.46772
# [135]	valid_0's rmse: 0.467704
# [136]	valid_0's rmse: 0.467664
# [137]	valid_0's rmse: 0.467655
# [138]	valid_0's rmse: 0.467635
# [139]	valid_0's rmse: 0.467625
# [140]	valid_0's rmse: 0.467623
# [141]	valid_0's rmse: 0.467611
# [142]	valid_0's rmse: 0.467655
# [143]	valid_0's rmse: 0.467612
# [144]	valid_0's rmse: 0.467498
# [145]	valid_0's rmse: 0.467477
# [146]	valid_0's rmse: 0.467439
# [147]	valid_0's rmse: 0.467418
# [148]	valid_0's rmse: 0.467403
# [149]	valid_0's rmse: 0.46735
# [150]	valid_0's rmse: 0.467367
# [151]	valid_0's rmse: 0.467274
# [152]	valid_0's rmse: 0.467192
# [153]	valid_0's rmse: 0.467148
# [154]	valid_0's rmse: 0.467148
# [155]	valid_0's rmse: 0.467085
# [156]	valid_0's rmse: 0.466998
# [157]	valid_0's rmse: 0.467025
# [158]	valid_0's rmse: 0.466863
# [159]	valid_0's rmse: 0.466883
# [160]	valid_0's rmse: 0.466862
# [161]	valid_0's rmse: 0.466826
# [162]	valid_0's rmse: 0.466846
# [163]	valid_0's rmse: 0.466832
# [164]	valid_0's rmse: 0.466762
# [165]	valid_0's rmse: 0.466765
# [166]	valid_0's rmse: 0.466702
# [167]	valid_0's rmse: 0.466705
# [168]	valid_0's rmse: 0.466737
# [169]	valid_0's rmse: 0.466752
# [170]	valid_0's rmse: 0.466759
# [171]	valid_0's rmse: 0.466777
# [172]	valid_0's rmse: 0.466773
# [173]	valid_0's rmse: 0.466787
# [174]	valid_0's rmse: 0.466744
# [175]	valid_0's rmse: 0.466725
# [176]	valid_0's rmse: 0.466696
# [177]	valid_0's rmse: 0.466703
# [178]	valid_0's rmse: 0.46653
# [179]	valid_0's rmse: 0.466556
# [180]	valid_0's rmse: 0.466546
# [181]	valid_0's rmse: 0.466557
# [182]	valid_0's rmse: 0.466545
# [183]	valid_0's rmse: 0.466526
# [184]	valid_0's rmse: 0.46652
# [185]	valid_0's rmse: 0.466493
# [186]	valid_0's rmse: 0.466477
# [187]	valid_0's rmse: 0.466419
# [188]	valid_0's rmse: 0.466326
# [189]	valid_0's rmse: 0.46628
# [190]	valid_0's rmse: 0.466235
# [191]	valid_0's rmse: 0.466247
# [192]	valid_0's rmse: 0.466257
# [193]	valid_0's rmse: 0.466218
# [194]	valid_0's rmse: 0.46628
# [195]	valid_0's rmse: 0.466343
# [196]	valid_0's rmse: 0.466305
# [197]	valid_0's rmse: 0.466292
# [198]	valid_0's rmse: 0.466197
# [199]	valid_0's rmse: 0.466077
# [200]	valid_0's rmse: 0.466076
# [201]	valid_0's rmse: 0.466076
# [202]	valid_0's rmse: 0.466017
# [203]	valid_0's rmse: 0.465966
# [204]	valid_0's rmse: 0.465963
# [205]	valid_0's rmse: 0.465962
# [206]	valid_0's rmse: 0.465827
# [207]	valid_0's rmse: 0.465852
# [208]	valid_0's rmse: 0.465898
# [209]	valid_0's rmse: 0.465936
# [210]	valid_0's rmse: 0.465946
# [211]	valid_0's rmse: 0.465961
# [212]	valid_0's rmse: 0.465931
# [213]	valid_0's rmse: 0.465885
# [214]	valid_0's rmse: 0.465811
# [215]	valid_0's rmse: 0.465771
# [216]	valid_0's rmse: 0.465718
# [217]	valid_0's rmse: 0.465676
# [218]	valid_0's rmse: 0.465683
# [219]	valid_0's rmse: 0.465733
# [220]	valid_0's rmse: 0.465744
# [221]	valid_0's rmse: 0.465711
# [222]	valid_0's rmse: 0.465737
# [223]	valid_0's rmse: 0.465733
# [224]	valid_0's rmse: 0.46564
# [225]	valid_0's rmse: 0.465645
# [226]	valid_0's rmse: 0.465632
# [227]	valid_0's rmse: 0.465571
# [228]	valid_0's rmse: 0.465552
# [229]	valid_0's rmse: 0.465592
# [230]	valid_0's rmse: 0.465595
# [231]	valid_0's rmse: 0.465561
# [232]	valid_0's rmse: 0.465509
# [233]	valid_0's rmse: 0.465489
# [234]	valid_0's rmse: 0.465554
# [235]	valid_0's rmse: 0.465573
# [236]	valid_0's rmse: 0.46559
# [237]	valid_0's rmse: 0.465576
# [238]	valid_0's rmse: 0.465555
# [239]	valid_0's rmse: 0.465562
# [240]	valid_0's rmse: 0.465567
# [241]	valid_0's rmse: 0.465601
# [242]	valid_0's rmse: 0.46566
# [243]	valid_0's rmse: 0.465724
# [244]	valid_0's rmse: 0.465723
# [245]	valid_0's rmse: 0.465741
# [246]	valid_0's rmse: 0.465724
# [247]	valid_0's rmse: 0.465669
# [248]	valid_0's rmse: 0.46566
# [249]	valid_0's rmse: 0.465667
# [250]	valid_0's rmse: 0.465668
# [251]	valid_0's rmse: 0.465683
# [252]	valid_0's rmse: 0.465698
# [253]	valid_0's rmse: 0.465659
# [254]	valid_0's rmse: 0.465658
# [255]	valid_0's rmse: 0.465642
# [256]	valid_0's rmse: 0.465739
# [257]	valid_0's rmse: 0.465694
# [258]	valid_0's rmse: 0.465702
# Early stopping, best iteration is:
# [233]	valid_0's rmse: 0.465489
# Start predicting...
# The rmse of prediction is: 0.465488611106
# Start training...
# [1]	valid_0's rmse: 0.601473
# Train until valid scores didn't improve in 25 rounds.
# [2]	valid_0's rmse: 0.591568
# [3]	valid_0's rmse: 0.582519
# [4]	valid_0's rmse: 0.574373
# [5]	valid_0's rmse: 0.566818
# [6]	valid_0's rmse: 0.559777
# [7]	valid_0's rmse: 0.553511
# [8]	valid_0's rmse: 0.547577
# [9]	valid_0's rmse: 0.542061
# [10]	valid_0's rmse: 0.53692
# [11]	valid_0's rmse: 0.532807
# [12]	valid_0's rmse: 0.529103
# [13]	valid_0's rmse: 0.525521
# [14]	valid_0's rmse: 0.522367
# [15]	valid_0's rmse: 0.518888
# [16]	valid_0's rmse: 0.516078
# [17]	valid_0's rmse: 0.51286
# [18]	valid_0's rmse: 0.509904
# [19]	valid_0's rmse: 0.507297
# [20]	valid_0's rmse: 0.505233
# [21]	valid_0's rmse: 0.502949
# [22]	valid_0's rmse: 0.501142
# [23]	valid_0's rmse: 0.499198
# [24]	valid_0's rmse: 0.497375
# [25]	valid_0's rmse: 0.495648
# [26]	valid_0's rmse: 0.494095
# [27]	valid_0's rmse: 0.492714
# [28]	valid_0's rmse: 0.4913
# [29]	valid_0's rmse: 0.490073
# [30]	valid_0's rmse: 0.488824
# [31]	valid_0's rmse: 0.487802
# [32]	valid_0's rmse: 0.486946
# [33]	valid_0's rmse: 0.486219
# [34]	valid_0's rmse: 0.485278
# [35]	valid_0's rmse: 0.484524
# [36]	valid_0's rmse: 0.48372
# [37]	valid_0's rmse: 0.482956
# [38]	valid_0's rmse: 0.482415
# [39]	valid_0's rmse: 0.481754
# [40]	valid_0's rmse: 0.481138
# [41]	valid_0's rmse: 0.480597
# [42]	valid_0's rmse: 0.48
# [43]	valid_0's rmse: 0.479492
# [44]	valid_0's rmse: 0.479019
# [45]	valid_0's rmse: 0.478622
# [46]	valid_0's rmse: 0.478227
# [47]	valid_0's rmse: 0.477853
# [48]	valid_0's rmse: 0.477385
# [49]	valid_0's rmse: 0.477021
# [50]	valid_0's rmse: 0.476625
# [51]	valid_0's rmse: 0.47632
# [52]	valid_0's rmse: 0.475991
# [53]	valid_0's rmse: 0.475716
# [54]	valid_0's rmse: 0.475437
# [55]	valid_0's rmse: 0.475147
# [56]	valid_0's rmse: 0.474889
# [57]	valid_0's rmse: 0.474541
# [58]	valid_0's rmse: 0.47432
# [59]	valid_0's rmse: 0.474125
# [60]	valid_0's rmse: 0.473987
# [61]	valid_0's rmse: 0.473818
# [62]	valid_0's rmse: 0.47368
# [63]	valid_0's rmse: 0.473555
# [64]	valid_0's rmse: 0.473438
# [65]	valid_0's rmse: 0.473255
# [66]	valid_0's rmse: 0.473025
# [67]	valid_0's rmse: 0.472928
# [68]	valid_0's rmse: 0.472651
# [69]	valid_0's rmse: 0.472387
# [70]	valid_0's rmse: 0.472252
# [71]	valid_0's rmse: 0.472031
# [72]	valid_0's rmse: 0.471901
# [73]	valid_0's rmse: 0.471831
# [74]	valid_0's rmse: 0.471604
# [75]	valid_0's rmse: 0.471402
# [76]	valid_0's rmse: 0.471313
# [77]	valid_0's rmse: 0.471249
# [78]	valid_0's rmse: 0.471119
# [79]	valid_0's rmse: 0.471033
# [80]	valid_0's rmse: 0.47084
# [81]	valid_0's rmse: 0.470589
# [82]	valid_0's rmse: 0.470391
# [83]	valid_0's rmse: 0.470314
# [84]	valid_0's rmse: 0.470222
# [85]	valid_0's rmse: 0.469969
# [86]	valid_0's rmse: 0.469716
# [87]	valid_0's rmse: 0.469664
# [88]	valid_0's rmse: 0.469535
# [89]	valid_0's rmse: 0.469461
# [90]	valid_0's rmse: 0.469428
# [91]	valid_0's rmse: 0.469333
# [92]	valid_0's rmse: 0.469292
# [93]	valid_0's rmse: 0.469229
# [94]	valid_0's rmse: 0.469152
# [95]	valid_0's rmse: 0.469049
# [96]	valid_0's rmse: 0.468942
# [97]	valid_0's rmse: 0.468853
# [98]	valid_0's rmse: 0.468774
# [99]	valid_0's rmse: 0.468748
# [100]	valid_0's rmse: 0.468709
# [101]	valid_0's rmse: 0.46867
# [102]	valid_0's rmse: 0.468602
# [103]	valid_0's rmse: 0.468638
# [104]	valid_0's rmse: 0.468614
# [105]	valid_0's rmse: 0.468465
# [106]	valid_0's rmse: 0.468376
# [107]	valid_0's rmse: 0.468247
# [108]	valid_0's rmse: 0.468245
# [109]	valid_0's rmse: 0.46816
# [110]	valid_0's rmse: 0.468091
# [111]	valid_0's rmse: 0.467927
# [112]	valid_0's rmse: 0.467804
# [113]	valid_0's rmse: 0.467779
# [114]	valid_0's rmse: 0.467817
# [115]	valid_0's rmse: 0.46774
# [116]	valid_0's rmse: 0.467757
# [117]	valid_0's rmse: 0.467763
# [118]	valid_0's rmse: 0.467712
# [119]	valid_0's rmse: 0.46768
# [120]	valid_0's rmse: 0.467621
# [121]	valid_0's rmse: 0.467421
# [122]	valid_0's rmse: 0.467331
# [123]	valid_0's rmse: 0.467188
# [124]	valid_0's rmse: 0.467169
# [125]	valid_0's rmse: 0.466902
# [126]	valid_0's rmse: 0.466887
# [127]	valid_0's rmse: 0.466865
# [128]	valid_0's rmse: 0.466843
# [129]	valid_0's rmse: 0.466837
# [130]	valid_0's rmse: 0.46679
# [131]	valid_0's rmse: 0.466774
# [132]	valid_0's rmse: 0.466723
# [133]	valid_0's rmse: 0.466683
# [134]	valid_0's rmse: 0.466665
# [135]	valid_0's rmse: 0.466452
# [136]	valid_0's rmse: 0.466282
# [137]	valid_0's rmse: 0.466185
# [138]	valid_0's rmse: 0.466128
# [139]	valid_0's rmse: 0.466079
# [140]	valid_0's rmse: 0.466079
# [141]	valid_0's rmse: 0.466084
# [142]	valid_0's rmse: 0.466039
# [143]	valid_0's rmse: 0.465993
# [144]	valid_0's rmse: 0.465925
# [145]	valid_0's rmse: 0.465907
# [146]	valid_0's rmse: 0.465839
# [147]	valid_0's rmse: 0.465734
# [148]	valid_0's rmse: 0.46574
# [149]	valid_0's rmse: 0.465619
# [150]	valid_0's rmse: 0.465597
# [151]	valid_0's rmse: 0.465584
# [152]	valid_0's rmse: 0.465575
# [153]	valid_0's rmse: 0.465514
# [154]	valid_0's rmse: 0.465527
# [155]	valid_0's rmse: 0.465499
# [156]	valid_0's rmse: 0.46545
# [157]	valid_0's rmse: 0.465415
# [158]	valid_0's rmse: 0.465365
# [159]	valid_0's rmse: 0.465341
# [160]	valid_0's rmse: 0.465391
# [161]	valid_0's rmse: 0.465411
# [162]	valid_0's rmse: 0.465382
# [163]	valid_0's rmse: 0.465312
# [164]	valid_0's rmse: 0.465237
# [165]	valid_0's rmse: 0.465274
# [166]	valid_0's rmse: 0.465259
# [167]	valid_0's rmse: 0.465294
# [168]	valid_0's rmse: 0.465237
# [169]	valid_0's rmse: 0.465196
# [170]	valid_0's rmse: 0.465175
# [171]	valid_0's rmse: 0.465137
# [172]	valid_0's rmse: 0.465149
# [173]	valid_0's rmse: 0.465139
# [174]	valid_0's rmse: 0.465059
# [175]	valid_0's rmse: 0.464999
# [176]	valid_0's rmse: 0.465003
# [177]	valid_0's rmse: 0.464967
# [178]	valid_0's rmse: 0.464941
# [179]	valid_0's rmse: 0.464947
# [180]	valid_0's rmse: 0.464972
# [181]	valid_0's rmse: 0.464916
# [182]	valid_0's rmse: 0.464852
# [183]	valid_0's rmse: 0.464832
# [184]	valid_0's rmse: 0.464824
# [185]	valid_0's rmse: 0.464834
# [186]	valid_0's rmse: 0.464827
# [187]	valid_0's rmse: 0.464769
# [188]	valid_0's rmse: 0.464722
# [189]	valid_0's rmse: 0.464747
# [190]	valid_0's rmse: 0.464734
# [191]	valid_0's rmse: 0.464733
# [192]	valid_0's rmse: 0.464718
# [193]	valid_0's rmse: 0.464659
# [194]	valid_0's rmse: 0.464586
# [195]	valid_0's rmse: 0.464614
# [196]	valid_0's rmse: 0.464592
# [197]	valid_0's rmse: 0.464613
# [198]	valid_0's rmse: 0.464582
# [199]	valid_0's rmse: 0.464605
# [200]	valid_0's rmse: 0.464667
# [201]	valid_0's rmse: 0.464647
# [202]	valid_0's rmse: 0.46462
# [203]	valid_0's rmse: 0.464591
# [204]	valid_0's rmse: 0.464545
# [205]	valid_0's rmse: 0.464565
# [206]	valid_0's rmse: 0.464543
# [207]	valid_0's rmse: 0.464539
# [208]	valid_0's rmse: 0.464526
# [209]	valid_0's rmse: 0.464554
# [210]	valid_0's rmse: 0.46457
# [211]	valid_0's rmse: 0.46459
# [212]	valid_0's rmse: 0.464497
# [213]	valid_0's rmse: 0.464475
# [214]	valid_0's rmse: 0.464452
# [215]	valid_0's rmse: 0.464455
# [216]	valid_0's rmse: 0.464362
# [217]	valid_0's rmse: 0.464378
# [218]	valid_0's rmse: 0.464344
# [219]	valid_0's rmse: 0.464344
# [220]	valid_0's rmse: 0.464312
# [221]	valid_0's rmse: 0.4643
# [222]	valid_0's rmse: 0.464261
# [223]	valid_0's rmse: 0.464296
# [224]	valid_0's rmse: 0.464266
# [225]	valid_0's rmse: 0.464284
# [226]	valid_0's rmse: 0.46428
# [227]	valid_0's rmse: 0.464317
# [228]	valid_0's rmse: 0.464262
# [229]	valid_0's rmse: 0.464285
# [230]	valid_0's rmse: 0.464269
# [231]	valid_0's rmse: 0.464293
# [232]	valid_0's rmse: 0.464273
# [233]	valid_0's rmse: 0.464307
# [234]	valid_0's rmse: 0.464316
# [235]	valid_0's rmse: 0.464325
# [236]	valid_0's rmse: 0.464248
# [237]	valid_0's rmse: 0.464284
# [238]	valid_0's rmse: 0.464253
# [239]	valid_0's rmse: 0.464265
# [240]	valid_0's rmse: 0.46422
# [241]	valid_0's rmse: 0.464214
# [242]	valid_0's rmse: 0.464233
# [243]	valid_0's rmse: 0.464271
# [244]	valid_0's rmse: 0.464334
# [245]	valid_0's rmse: 0.464355
# [246]	valid_0's rmse: 0.46431
# [247]	valid_0's rmse: 0.464279
# [248]	valid_0's rmse: 0.46429
# [249]	valid_0's rmse: 0.464288
# [250]	valid_0's rmse: 0.464287
# [251]	valid_0's rmse: 0.464324
# [252]	valid_0's rmse: 0.464367
# [253]	valid_0's rmse: 0.464325
# [254]	valid_0's rmse: 0.464335
# [255]	valid_0's rmse: 0.464325
# [256]	valid_0's rmse: 0.464313
# [257]	valid_0's rmse: 0.464291
# [258]	valid_0's rmse: 0.464285
# [259]	valid_0's rmse: 0.464279
# [260]	valid_0's rmse: 0.464306
# [261]	valid_0's rmse: 0.464291
# [262]	valid_0's rmse: 0.46428
# [263]	valid_0's rmse: 0.464271
# [264]	valid_0's rmse: 0.464288
# [265]	valid_0's rmse: 0.464228
# [266]	valid_0's rmse: 0.464214
# [267]	valid_0's rmse: 0.464208
# [268]	valid_0's rmse: 0.464207
# [269]	valid_0's rmse: 0.464206
# [270]	valid_0's rmse: 0.464206
# [271]	valid_0's rmse: 0.464244
# [272]	valid_0's rmse: 0.464285
# [273]	valid_0's rmse: 0.464341
# [274]	valid_0's rmse: 0.464349
# [275]	valid_0's rmse: 0.464363
# [276]	valid_0's rmse: 0.464347
# [277]	valid_0's rmse: 0.464348
# [278]	valid_0's rmse: 0.464333
# [279]	valid_0's rmse: 0.464288
# [280]	valid_0's rmse: 0.464352
# [281]	valid_0's rmse: 0.46432
# [282]	valid_0's rmse: 0.464385
# [283]	valid_0's rmse: 0.464425
# [284]	valid_0's rmse: 0.464441
# [285]	valid_0's rmse: 0.464437
# [286]	valid_0's rmse: 0.464459
# [287]	valid_0's rmse: 0.464501
# [288]	valid_0's rmse: 0.464436
# [289]	valid_0's rmse: 0.464432
# [290]	valid_0's rmse: 0.464438
# [291]	valid_0's rmse: 0.464421
# [292]	valid_0's rmse: 0.464415
# [293]	valid_0's rmse: 0.464408
# [294]	valid_0's rmse: 0.464379
# Early stopping, best iteration is:
# [269]	valid_0's rmse: 0.464206
# Start predicting...
# The rmse of prediction is: 0.464205793162
# Start training...
# [1]	valid_0's rmse: 0.562349
# Train until valid scores didn't improve in 25 rounds.
# [2]	valid_0's rmse: 0.554214
# [3]	valid_0's rmse: 0.550524
# [4]	valid_0's rmse: 0.547024
# [5]	valid_0's rmse: 0.540335
# [6]	valid_0's rmse: 0.534013
# [7]	valid_0's rmse: 0.528255
# [8]	valid_0's rmse: 0.522921
# [9]	valid_0's rmse: 0.517926
# [10]	valid_0's rmse: 0.513288
# [11]	valid_0's rmse: 0.508882
# [12]	valid_0's rmse: 0.504916
# [13]	valid_0's rmse: 0.501452
# [14]	valid_0's rmse: 0.498041
# [15]	valid_0's rmse: 0.496369
# [16]	valid_0's rmse: 0.493069
# [17]	valid_0's rmse: 0.490207
# [18]	valid_0's rmse: 0.48747
# [19]	valid_0's rmse: 0.484974
# [20]	valid_0's rmse: 0.482716
# [21]	valid_0's rmse: 0.481486
# [22]	valid_0's rmse: 0.479542
# [23]	valid_0's rmse: 0.477727
# [24]	valid_0's rmse: 0.47616
# [25]	valid_0's rmse: 0.474592
# [26]	valid_0's rmse: 0.473231
# [27]	valid_0's rmse: 0.471782
# [28]	valid_0's rmse: 0.47054
# [29]	valid_0's rmse: 0.469868
# [30]	valid_0's rmse: 0.468813
# [31]	valid_0's rmse: 0.467827
# [32]	valid_0's rmse: 0.466625
# [33]	valid_0's rmse: 0.465799
# [34]	valid_0's rmse: 0.465416
# [35]	valid_0's rmse: 0.464633
# [36]	valid_0's rmse: 0.464082
# [37]	valid_0's rmse: 0.463444
# [38]	valid_0's rmse: 0.462741
# [39]	valid_0's rmse: 0.462071
# [40]	valid_0's rmse: 0.461298
# [41]	valid_0's rmse: 0.460746
# [42]	valid_0's rmse: 0.460415
# [43]	valid_0's rmse: 0.459963
# [44]	valid_0's rmse: 0.459406
# [45]	valid_0's rmse: 0.459086
# [46]	valid_0's rmse: 0.458622
# [47]	valid_0's rmse: 0.458371
# [48]	valid_0's rmse: 0.457979
# [49]	valid_0's rmse: 0.45759
# [50]	valid_0's rmse: 0.457184
# [51]	valid_0's rmse: 0.45683
# [52]	valid_0's rmse: 0.456558
# [53]	valid_0's rmse: 0.456126
# [54]	valid_0's rmse: 0.45592
# [55]	valid_0's rmse: 0.455726
# [56]	valid_0's rmse: 0.455468
# [57]	valid_0's rmse: 0.455263
# [58]	valid_0's rmse: 0.454983
# [59]	valid_0's rmse: 0.45479
# [60]	valid_0's rmse: 0.45455
# [61]	valid_0's rmse: 0.454493
# [62]	valid_0's rmse: 0.454292
# [63]	valid_0's rmse: 0.454055
# [64]	valid_0's rmse: 0.45389
# [65]	valid_0's rmse: 0.453785
# [66]	valid_0's rmse: 0.45364
# [67]	valid_0's rmse: 0.453426
# [68]	valid_0's rmse: 0.453316
# [69]	valid_0's rmse: 0.453291
# [70]	valid_0's rmse: 0.453155
# [71]	valid_0's rmse: 0.453031
# [72]	valid_0's rmse: 0.452863
# [73]	valid_0's rmse: 0.452794
# [74]	valid_0's rmse: 0.452689
# [75]	valid_0's rmse: 0.452585
# [76]	valid_0's rmse: 0.452434
# [77]	valid_0's rmse: 0.452299
# [78]	valid_0's rmse: 0.452256
# [79]	valid_0's rmse: 0.452168
# [80]	valid_0's rmse: 0.452119
# [81]	valid_0's rmse: 0.45204
# [82]	valid_0's rmse: 0.451976
# [83]	valid_0's rmse: 0.451904
# [84]	valid_0's rmse: 0.451794
# [85]	valid_0's rmse: 0.451655
# [86]	valid_0's rmse: 0.451549
# [87]	valid_0's rmse: 0.451411
# [88]	valid_0's rmse: 0.451424
# [89]	valid_0's rmse: 0.451367
# [90]	valid_0's rmse: 0.451257
# [91]	valid_0's rmse: 0.45122
# [92]	valid_0's rmse: 0.451188
# [93]	valid_0's rmse: 0.451169
# [94]	valid_0's rmse: 0.451074
# [95]	valid_0's rmse: 0.450942
# [96]	valid_0's rmse: 0.450887
# [97]	valid_0's rmse: 0.450854
# [98]	valid_0's rmse: 0.450741
# [99]	valid_0's rmse: 0.45069
# [100]	valid_0's rmse: 0.450637
# [101]	valid_0's rmse: 0.450714
# [102]	valid_0's rmse: 0.450606
# [103]	valid_0's rmse: 0.450557
# [104]	valid_0's rmse: 0.450417
# [105]	valid_0's rmse: 0.450365
# [106]	valid_0's rmse: 0.450252
# [107]	valid_0's rmse: 0.450205
# [108]	valid_0's rmse: 0.450077
# [109]	valid_0's rmse: 0.450093
# [110]	valid_0's rmse: 0.450016
# [111]	valid_0's rmse: 0.449955
# [112]	valid_0's rmse: 0.449882
# [113]	valid_0's rmse: 0.449835
# [114]	valid_0's rmse: 0.449883
# [115]	valid_0's rmse: 0.449852
# [116]	valid_0's rmse: 0.449851
# [117]	valid_0's rmse: 0.449755
# [118]	valid_0's rmse: 0.44957
# [119]	valid_0's rmse: 0.44949
# [120]	valid_0's rmse: 0.449479
# [121]	valid_0's rmse: 0.449406
# [122]	valid_0's rmse: 0.449442
# [123]	valid_0's rmse: 0.449353
# [124]	valid_0's rmse: 0.449318
# [125]	valid_0's rmse: 0.449327
# [126]	valid_0's rmse: 0.449281
# [127]	valid_0's rmse: 0.449199
# [128]	valid_0's rmse: 0.449186
# [129]	valid_0's rmse: 0.449139
# [130]	valid_0's rmse: 0.449017
# [131]	valid_0's rmse: 0.449035
# [132]	valid_0's rmse: 0.449066
# [133]	valid_0's rmse: 0.449084
# [134]	valid_0's rmse: 0.449017
# [135]	valid_0's rmse: 0.449052
# [136]	valid_0's rmse: 0.449058
# [137]	valid_0's rmse: 0.449067
# [138]	valid_0's rmse: 0.449053
# [139]	valid_0's rmse: 0.449034
# [140]	valid_0's rmse: 0.449038
# [141]	valid_0's rmse: 0.449022
# [142]	valid_0's rmse: 0.449007
# [143]	valid_0's rmse: 0.448996
# [144]	valid_0's rmse: 0.44891
# [145]	valid_0's rmse: 0.448855
# [146]	valid_0's rmse: 0.448784
# [147]	valid_0's rmse: 0.448816
# [148]	valid_0's rmse: 0.448848
# [149]	valid_0's rmse: 0.448894
# [150]	valid_0's rmse: 0.448835
# [151]	valid_0's rmse: 0.448802
# [152]	valid_0's rmse: 0.448799
# [153]	valid_0's rmse: 0.448818
# [154]	valid_0's rmse: 0.448728
# [155]	valid_0's rmse: 0.448816
# [156]	valid_0's rmse: 0.448829
# [157]	valid_0's rmse: 0.44887
# [158]	valid_0's rmse: 0.448848
# [159]	valid_0's rmse: 0.448768
# [160]	valid_0's rmse: 0.448754
# [161]	valid_0's rmse: 0.448786
# [162]	valid_0's rmse: 0.448717
# [163]	valid_0's rmse: 0.448748
# [164]	valid_0's rmse: 0.448683
# [165]	valid_0's rmse: 0.44865
# [166]	valid_0's rmse: 0.448693
# [167]	valid_0's rmse: 0.448632
# [168]	valid_0's rmse: 0.448678
# [169]	valid_0's rmse: 0.448693
# [170]	valid_0's rmse: 0.448664
# [171]	valid_0's rmse: 0.448673
# [172]	valid_0's rmse: 0.448732
# [173]	valid_0's rmse: 0.4487
# [174]	valid_0's rmse: 0.448681
# [175]	valid_0's rmse: 0.448711
# [176]	valid_0's rmse: 0.448721
# [177]	valid_0's rmse: 0.448729
# [178]	valid_0's rmse: 0.448718
# [179]	valid_0's rmse: 0.448653
# [180]	valid_0's rmse: 0.448683
# [181]	valid_0's rmse: 0.448611
# [182]	valid_0's rmse: 0.448608
# [183]	valid_0's rmse: 0.448628
# [184]	valid_0's rmse: 0.448667
# [185]	valid_0's rmse: 0.448637
# [186]	valid_0's rmse: 0.448664
# [187]	valid_0's rmse: 0.448645
# [188]	valid_0's rmse: 0.448642
# [189]	valid_0's rmse: 0.448621
# [190]	valid_0's rmse: 0.44864
# [191]	valid_0's rmse: 0.448662
# [192]	valid_0's rmse: 0.448707
# [193]	valid_0's rmse: 0.448584
# [194]	valid_0's rmse: 0.448579
# [195]	valid_0's rmse: 0.448557
# [196]	valid_0's rmse: 0.448546
# [197]	valid_0's rmse: 0.448599
# [198]	valid_0's rmse: 0.448611
# [199]	valid_0's rmse: 0.448623
# [200]	valid_0's rmse: 0.448622
# [201]	valid_0's rmse: 0.448652
# [202]	valid_0's rmse: 0.448637
# [203]	valid_0's rmse: 0.448649
# [204]	valid_0's rmse: 0.448624
# [205]	valid_0's rmse: 0.448656
# [206]	valid_0's rmse: 0.448634
# [207]	valid_0's rmse: 0.448601
# [208]	valid_0's rmse: 0.448673
# [209]	valid_0's rmse: 0.448674
# [210]	valid_0's rmse: 0.448704
# [211]	valid_0's rmse: 0.448716
# [212]	valid_0's rmse: 0.448688
# [213]	valid_0's rmse: 0.448687
# [214]	valid_0's rmse: 0.448757
# [215]	valid_0's rmse: 0.448757
# [216]	valid_0's rmse: 0.448726
# [217]	valid_0's rmse: 0.448675
# [218]	valid_0's rmse: 0.448674
# [219]	valid_0's rmse: 0.448692
# [220]	valid_0's rmse: 0.448712
# [221]	valid_0's rmse: 0.448701
# Early stopping, best iteration is:
# [196]	valid_0's rmse: 0.448546
# Start predicting...
# The rmse of prediction is: 0.44854618539
# Start training...
# [1]	valid_0's rmse: 0.570499
# Train until valid scores didn't improve in 25 rounds.
# [2]	valid_0's rmse: 0.569965
# [3]	valid_0's rmse: 0.569479
# [4]	valid_0's rmse: 0.569094
# [5]	valid_0's rmse: 0.568681
# [6]	valid_0's rmse: 0.568341
# [7]	valid_0's rmse: 0.568037
# [8]	valid_0's rmse: 0.567766
# [9]	valid_0's rmse: 0.567582
# [10]	valid_0's rmse: 0.567427
# [11]	valid_0's rmse: 0.567157
# [12]	valid_0's rmse: 0.566987
# [13]	valid_0's rmse: 0.566818
# [14]	valid_0's rmse: 0.566603
# [15]	valid_0's rmse: 0.566525
# [16]	valid_0's rmse: 0.566384
# [17]	valid_0's rmse: 0.566242
# [18]	valid_0's rmse: 0.566149
# [19]	valid_0's rmse: 0.566089
# [20]	valid_0's rmse: 0.565983
# [21]	valid_0's rmse: 0.565912
# [22]	valid_0's rmse: 0.565874
# [23]	valid_0's rmse: 0.565795
# [24]	valid_0's rmse: 0.56571
# [25]	valid_0's rmse: 0.565635
# [26]	valid_0's rmse: 0.565505
# [27]	valid_0's rmse: 0.565519
# [28]	valid_0's rmse: 0.5655
# [29]	valid_0's rmse: 0.565473
# [30]	valid_0's rmse: 0.565437
# [31]	valid_0's rmse: 0.565419
# [32]	valid_0's rmse: 0.56539
# [33]	valid_0's rmse: 0.565316
# [34]	valid_0's rmse: 0.565227
# [35]	valid_0's rmse: 0.565238
# [36]	valid_0's rmse: 0.5652
# [37]	valid_0's rmse: 0.565227
# [38]	valid_0's rmse: 0.565251
# [39]	valid_0's rmse: 0.565224
# [40]	valid_0's rmse: 0.565229
# [41]	valid_0's rmse: 0.565217
# [42]	valid_0's rmse: 0.565214
# [43]	valid_0's rmse: 0.565192
# [44]	valid_0's rmse: 0.565288
# [45]	valid_0's rmse: 0.565299
# [46]	valid_0's rmse: 0.565183
# [47]	valid_0's rmse: 0.565173
# [48]	valid_0's rmse: 0.56518
# [49]	valid_0's rmse: 0.565203
# [50]	valid_0's rmse: 0.565226
# [51]	valid_0's rmse: 0.565286
# [52]	valid_0's rmse: 0.565318
# [53]	valid_0's rmse: 0.565282
# [54]	valid_0's rmse: 0.565175
# [55]	valid_0's rmse: 0.565202
# [56]	valid_0's rmse: 0.565257
# [57]	valid_0's rmse: 0.565283
# [58]	valid_0's rmse: 0.565287
# [59]	valid_0's rmse: 0.565312
# [60]	valid_0's rmse: 0.565353
# [61]	valid_0's rmse: 0.565422
# [62]	valid_0's rmse: 0.565448
# [63]	valid_0's rmse: 0.565446
# [64]	valid_0's rmse: 0.565451
# [65]	valid_0's rmse: 0.565506
# [66]	valid_0's rmse: 0.565555
# [67]	valid_0's rmse: 0.565584
# [68]	valid_0's rmse: 0.565606
# [69]	valid_0's rmse: 0.565659
# [70]	valid_0's rmse: 0.565702
# [71]	valid_0's rmse: 0.565686
# [72]	valid_0's rmse: 0.565663
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.565173
# Start predicting...
# The rmse of prediction is: 0.565172817607
# Start training...
# [1]	valid_0's rmse: 0.562087
# Train until valid scores didn't improve in 25 rounds.
# [2]	valid_0's rmse: 0.553978
# [3]	valid_0's rmse: 0.546555
# [4]	valid_0's rmse: 0.539702
# [5]	valid_0's rmse: 0.53339
# [6]	valid_0's rmse: 0.527675
# [7]	valid_0's rmse: 0.523788
# [8]	valid_0's rmse: 0.518765
# [9]	valid_0's rmse: 0.514088
# [10]	valid_0's rmse: 0.511797
# [11]	valid_0's rmse: 0.507708
# [12]	valid_0's rmse: 0.503908
# [13]	valid_0's rmse: 0.500534
# [14]	valid_0's rmse: 0.498455
# [15]	valid_0's rmse: 0.496457
# [16]	valid_0's rmse: 0.493661
# [17]	valid_0's rmse: 0.491171
# [18]	valid_0's rmse: 0.488848
# [19]	valid_0's rmse: 0.486698
# [20]	valid_0's rmse: 0.484824
# [21]	valid_0's rmse: 0.483053
# [22]	valid_0's rmse: 0.481446
# [23]	valid_0's rmse: 0.480461
# [24]	valid_0's rmse: 0.478913
# [25]	valid_0's rmse: 0.477609
# [26]	valid_0's rmse: 0.476306
# [27]	valid_0's rmse: 0.475603
# [28]	valid_0's rmse: 0.474455
# [29]	valid_0's rmse: 0.473419
# [30]	valid_0's rmse: 0.472614
# [31]	valid_0's rmse: 0.472069
# [32]	valid_0's rmse: 0.471207
# [33]	valid_0's rmse: 0.47044
# [34]	valid_0's rmse: 0.469705
# [35]	valid_0's rmse: 0.469122
# [36]	valid_0's rmse: 0.468501
# [37]	valid_0's rmse: 0.467896
# [38]	valid_0's rmse: 0.467347
# [39]	valid_0's rmse: 0.466913
# [40]	valid_0's rmse: 0.466504
# [41]	valid_0's rmse: 0.466143
# [42]	valid_0's rmse: 0.465638
# [43]	valid_0's rmse: 0.465258
# [44]	valid_0's rmse: 0.464796
# [45]	valid_0's rmse: 0.464518
# [46]	valid_0's rmse: 0.464275
# [47]	valid_0's rmse: 0.463971
# [48]	valid_0's rmse: 0.463706
# [49]	valid_0's rmse: 0.463491
# [50]	valid_0's rmse: 0.463297
# [51]	valid_0's rmse: 0.462933
# [52]	valid_0's rmse: 0.46272
# [53]	valid_0's rmse: 0.462484
# [54]	valid_0's rmse: 0.462388
# [55]	valid_0's rmse: 0.462135
# [56]	valid_0's rmse: 0.462004
# [57]	valid_0's rmse: 0.461863
# [58]	valid_0's rmse: 0.461751
# [59]	valid_0's rmse: 0.461591
# [60]	valid_0's rmse: 0.461432
# [61]	valid_0's rmse: 0.461346
# [62]	valid_0's rmse: 0.461227
# [63]	valid_0's rmse: 0.461021
# [64]	valid_0's rmse: 0.460931
# [65]	valid_0's rmse: 0.460801
# [66]	valid_0's rmse: 0.460666
# [67]	valid_0's rmse: 0.46056
# [68]	valid_0's rmse: 0.46046
# [69]	valid_0's rmse: 0.460428
# [70]	valid_0's rmse: 0.460298
# [71]	valid_0's rmse: 0.460301
# [72]	valid_0's rmse: 0.460186
# [73]	valid_0's rmse: 0.460099
# [74]	valid_0's rmse: 0.460006
# [75]	valid_0's rmse: 0.459933
# [76]	valid_0's rmse: 0.459852
# [77]	valid_0's rmse: 0.4598
# [78]	valid_0's rmse: 0.459526
# [79]	valid_0's rmse: 0.459467
# [80]	valid_0's rmse: 0.4594
# [81]	valid_0's rmse: 0.459368
# [82]	valid_0's rmse: 0.459382
# [83]	valid_0's rmse: 0.459262
# [84]	valid_0's rmse: 0.459122
# [85]	valid_0's rmse: 0.459112
# [86]	valid_0's rmse: 0.45894
# [87]	valid_0's rmse: 0.458858
# [88]	valid_0's rmse: 0.458811
# [89]	valid_0's rmse: 0.458773
# [90]	valid_0's rmse: 0.458744
# [91]	valid_0's rmse: 0.458758
# [92]	valid_0's rmse: 0.458794
# [93]	valid_0's rmse: 0.458824
# [94]	valid_0's rmse: 0.458844
# [95]	valid_0's rmse: 0.458832
# [96]	valid_0's rmse: 0.458803
# [97]	valid_0's rmse: 0.45882
# [98]	valid_0's rmse: 0.458769
# [99]	valid_0's rmse: 0.458717
# [100]	valid_0's rmse: 0.458657
# [101]	valid_0's rmse: 0.458651
# [102]	valid_0's rmse: 0.458654
# [103]	valid_0's rmse: 0.458612
# [104]	valid_0's rmse: 0.458551
# [105]	valid_0's rmse: 0.458531
# [106]	valid_0's rmse: 0.458517
# [107]	valid_0's rmse: 0.458448
# [108]	valid_0's rmse: 0.458508
# [109]	valid_0's rmse: 0.458485
# [110]	valid_0's rmse: 0.458461
# [111]	valid_0's rmse: 0.45844
# [112]	valid_0's rmse: 0.458467
# [113]	valid_0's rmse: 0.458412
# [114]	valid_0's rmse: 0.458447
# [115]	valid_0's rmse: 0.45836
# [116]	valid_0's rmse: 0.458274
# [117]	valid_0's rmse: 0.458258
# [118]	valid_0's rmse: 0.458253
# [119]	valid_0's rmse: 0.458185
# [120]	valid_0's rmse: 0.458156
# [121]	valid_0's rmse: 0.458194
# [122]	valid_0's rmse: 0.458155
# [123]	valid_0's rmse: 0.458087
# [124]	valid_0's rmse: 0.458064
# [125]	valid_0's rmse: 0.458113
# [126]	valid_0's rmse: 0.458165
# [127]	valid_0's rmse: 0.458011
# [128]	valid_0's rmse: 0.458042
# [129]	valid_0's rmse: 0.458013
# [130]	valid_0's rmse: 0.458008
# [131]	valid_0's rmse: 0.458052
# [132]	valid_0's rmse: 0.458075
# [133]	valid_0's rmse: 0.45802
# [134]	valid_0's rmse: 0.458007
# [135]	valid_0's rmse: 0.457794
# [136]	valid_0's rmse: 0.457803
# [137]	valid_0's rmse: 0.457827
# [138]	valid_0's rmse: 0.4579
# [139]	valid_0's rmse: 0.457754
# [140]	valid_0's rmse: 0.457766
# [141]	valid_0's rmse: 0.457767
# [142]	valid_0's rmse: 0.457753
# [143]	valid_0's rmse: 0.457757
# [144]	valid_0's rmse: 0.457726
# [145]	valid_0's rmse: 0.457778
# [146]	valid_0's rmse: 0.457747
# [147]	valid_0's rmse: 0.457701
# [148]	valid_0's rmse: 0.457739
# [149]	valid_0's rmse: 0.457688
# [150]	valid_0's rmse: 0.457696
# [151]	valid_0's rmse: 0.457701
# [152]	valid_0's rmse: 0.457742
# [153]	valid_0's rmse: 0.457785
# [154]	valid_0's rmse: 0.457809
# [155]	valid_0's rmse: 0.45778
# [156]	valid_0's rmse: 0.45778
# [157]	valid_0's rmse: 0.457781
# [158]	valid_0's rmse: 0.457794
# [159]	valid_0's rmse: 0.457821
# [160]	valid_0's rmse: 0.457765
# [161]	valid_0's rmse: 0.457757
# [162]	valid_0's rmse: 0.45779
# [163]	valid_0's rmse: 0.457785
# [164]	valid_0's rmse: 0.457778
# [165]	valid_0's rmse: 0.457739
# [166]	valid_0's rmse: 0.457729
# [167]	valid_0's rmse: 0.45771
# [168]	valid_0's rmse: 0.457682
# [169]	valid_0's rmse: 0.457629
# [170]	valid_0's rmse: 0.457564
# [171]	valid_0's rmse: 0.457576
# [172]	valid_0's rmse: 0.457587
# [173]	valid_0's rmse: 0.457535
# [174]	valid_0's rmse: 0.457494
# [175]	valid_0's rmse: 0.457551
# [176]	valid_0's rmse: 0.457581
# [177]	valid_0's rmse: 0.457592
# [178]	valid_0's rmse: 0.457409
# [179]	valid_0's rmse: 0.4574
# [180]	valid_0's rmse: 0.457385
# [181]	valid_0's rmse: 0.457406
# [182]	valid_0's rmse: 0.457438
# [183]	valid_0's rmse: 0.457432
# [184]	valid_0's rmse: 0.457434
# [185]	valid_0's rmse: 0.457475
# [186]	valid_0's rmse: 0.4575
# [187]	valid_0's rmse: 0.457562
# [188]	valid_0's rmse: 0.457586
# [189]	valid_0's rmse: 0.457592
# [190]	valid_0's rmse: 0.457623
# [191]	valid_0's rmse: 0.457628
# [192]	valid_0's rmse: 0.457645
# [193]	valid_0's rmse: 0.457699
# [194]	valid_0's rmse: 0.457695
# [195]	valid_0's rmse: 0.457674
# [196]	valid_0's rmse: 0.457705
# [197]	valid_0's rmse: 0.457688
# [198]	valid_0's rmse: 0.457692
# [199]	valid_0's rmse: 0.457756
# [200]	valid_0's rmse: 0.45774
# [201]	valid_0's rmse: 0.457669
# [202]	valid_0's rmse: 0.457673
# [203]	valid_0's rmse: 0.457696
# [204]	valid_0's rmse: 0.457676
# [205]	valid_0's rmse: 0.457654
# Early stopping, best iteration is:
# [180]	valid_0's rmse: 0.457385
# Start predicting...
# The rmse of prediction is: 0.457385396854

# %%
"""y_test_pred = np.exp(y_test_pred)
df_sub = pd.DataFrame({'id': id_test, 'price_doc': y_test_pred})
print(df_sub)
df_sub.to_csv('submission.csv', index=False)
"""

# %% [markdown]
# # XGBoost

# %%
RS = 20170501

df_train = [df_train1, df_train2, df_train3, df_train4, df_train5]
ylogs = [y_log, y_log, y_log_imputation,y_log_imputation,y_log_imputation]
#df_train = [df_train3 , df_train33]
#ylogs = [y_log_imputation, y_log2]
rmse_xgboost = []
elapsed_xgboost = []

xgb_params = {
    'eta': 0.05,
    'max_depth': 5,
    'subsample': 1,
    'colsample_bytree': 0.8,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

for i in range(len(df_train)):
    X_train, X_test, y_train, y_test = train_test_split(df_train[i], ylogs[i], test_size=0.2, random_state = 1234)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 1234)
    
    df_columns = df_train[i].columns
    dtrain_all = xgb.DMatrix(df_train[i], ylogs[i], feature_names=df_columns)
    dtrain = xgb.DMatrix(X_train, y_train, feature_names=df_columns)
    dval = xgb.DMatrix(X_val, y_val, feature_names=df_columns)
    dtest = xgb.DMatrix(X_test, feature_names=df_columns)
    
    partial_model = xgb.train(xgb_params, dtrain, num_boost_round=1000, evals=[(dval, 'val')],
                       early_stopping_rounds=20, verbose_eval=20)

    num_boost_round = partial_model.best_iteration
    model = xgb.train(dict(xgb_params, silent=0), dtrain_all, num_boost_round=num_boost_round)
    
    print('Start predicting...')
    start = time.time()
    # predict
    y_pred = model.predict(dtest)
    # eval
    elapsed_xgboost.append(time.time()-start)
    print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
    rmse_xgboost.append(mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# [0]	val-rmse:14.3501
# Will train until val-rmse hasn't improved in 20 rounds.
# [20]	val-rmse:5.16068
# [40]	val-rmse:1.90007
# [60]	val-rmse:0.813487
# [80]	val-rmse:0.533435
# [100]	val-rmse:0.48702
# [120]	val-rmse:0.479482
# [140]	val-rmse:0.47823
# [160]	val-rmse:0.477422
# [180]	val-rmse:0.477473
# Stopping. Best iteration:
# [163]	val-rmse:0.477266
#
# Start predicting...
# The rmse of prediction is: 0.424756552898
# [0]	val-rmse:14.3501
# Will train until val-rmse hasn't improved in 20 rounds.
# [20]	val-rmse:5.16092
# [40]	val-rmse:1.90196
# [60]	val-rmse:0.814655
# [80]	val-rmse:0.535511
# [100]	val-rmse:0.488224
# [120]	val-rmse:0.480956
# [140]	val-rmse:0.479293
# [160]	val-rmse:0.477757
# [180]	val-rmse:0.477152
# [200]	val-rmse:0.476885
# Stopping. Best iteration:
# [194]	val-rmse:0.476788
#
# Start predicting...
# The rmse of prediction is: 0.4162183334
# [0]	val-rmse:14.3358
# Will train until val-rmse hasn't improved in 20 rounds.
# [20]	val-rmse:5.15543
# [40]	val-rmse:1.8995
# [60]	val-rmse:0.811123
# [80]	val-rmse:0.531069
# [100]	val-rmse:0.484326
# [120]	val-rmse:0.478448
# [140]	val-rmse:0.477684
# [160]	val-rmse:0.477721
# Stopping. Best iteration:
# [149]	val-rmse:0.477377
#
# Start predicting...
# The rmse of prediction is: 0.42048923755
# [0]	val-rmse:14.3356
# Will train until val-rmse hasn't improved in 20 rounds.
# [20]	val-rmse:5.15595
# [40]	val-rmse:1.91529
# [60]	val-rmse:0.866963
# [80]	val-rmse:0.621752
# [100]	val-rmse:0.586466
# [120]	val-rmse:0.583548
# [140]	val-rmse:0.583947
# Stopping. Best iteration:
# [126]	val-rmse:0.583499
#
# Start predicting...
# The rmse of prediction is: 0.564093105771
# [0]	val-rmse:14.336
# Will train until val-rmse hasn't improved in 20 rounds.
# [20]	val-rmse:5.15676
# [40]	val-rmse:1.90301
# [60]	val-rmse:0.818603
# [80]	val-rmse:0.541418
# [100]	val-rmse:0.495598
# [120]	val-rmse:0.489621
# [140]	val-rmse:0.489125
# [160]	val-rmse:0.488942
# Stopping. Best iteration:
# [155]	val-rmse:0.488897
#
# Start predicting...
# The rmse of prediction is: 0.450074912231

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(n_estimators=10, random_state=1234)

df_train = [df_train3, df_train4]
ylogs = [y_log_imputation,y_log_imputation]
rmse_rfr = []
elapsed_rfr = []

for i in range(len(df_train)):
    X_train, X_test, y_train, y_test = train_test_split(df_train[i], ylogs[i], test_size=0.2, random_state = 1234)
    start = time.time()
    clf.fit(X_train, y_train)
    elapsed_rfr.append(time.time()-start)
    print('Start predicting...')
    # predict
    y_pred = clf.predict(X_test)
    # eval
    print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
    rmse_rfr.append(mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# Start predicting...
# The rmse of prediction is: 0.476434437172
# Start predicting...
# The rmse of prediction is: 0.621957480402

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Lasso

clf = Ridge()

df_train = [df_train3, df_train4]
ylogs = [y_log_imputation,y_log_imputation]
rmse_rr = []
elapsed_rr = []

for i in range(len(df_train)):
    X_train, X_test, y_train, y_test = train_test_split(df_train[i], ylogs[i], test_size=0.2, random_state = 1234)
    start = time.time()
    clf.fit(X_train, y_train)
    elapsed_rr.append(time.time()-start)
    print('Start predicting...')
    # predict
    y_pred = clf.predict(X_test)
    # eval
    print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
    rmse_rr.append(mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# Start predicting...
# The rmse of prediction is: 0.457902518682
# Start predicting...
# The rmse of prediction is: 0.563589071684

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Ridge

clf = Lasso()

df_train = [df_train3, df_train4]
ylogs = [y_log_imputation,y_log_imputation]
rmse_lr = []
elapsed_lr = []

for i in range(len(df_train)):
    X_train, X_test, y_train, y_test = train_test_split(df_train[i], ylogs[i], test_size=0.2, random_state = 1234)
    start = time.time()
    clf.fit(X_train, y_train)
    elapsed_lr.append(time.time()-start)
    print('Start predicting...')
    # predict
    y_pred = clf.predict(X_test)
    # eval
    print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
    rmse_lr.append(mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# Start predicting...
# The rmse of prediction is: 0.570946564866
# Start predicting...
# The rmse of prediction is: 0.570946564866

# %%
print("BENCHMARK")
for i in range(5):
    print("The RMSE for BENCHMARK for df_train{} is {}".format(i+1, rmse_bm[i]))
print("\n",'-'*68,"\n")
print("LIGHT GBM")
for i in range(5):
    print("The RMSE for light GBM for df_train{} is {}".format(i+1, rmse_lgbm[i]))
    print("Training took {} s".format(round(elapsed_lgbm[i],2)))
print("\n",'-'*68,"\n")
print("XGBOOST")
for i in range(5):
    print("The RMSE for XGBoost for df_train{} is {}".format(i+1, rmse_xgboost[i]))
    print("Training took {} s".format(round(elapsed_xgboost[i],2)))
    
print("\n",'-'*68,"\n")
print("RANDOM FOREST REGRESSOR")
for i in range(2):
    print("The RMSE for light RFR for df_train{} is {}".format(i+3, rmse_rfr[i]))
    print("Training took {} s".format(round(elapsed_rfr[i],2)))
print("\n",'-'*68,"\n")
print("Ridge Regression")
for i in range(2):
    print("The RMSE for RIDGE REGRESSION for df_train{} is {}".format(i+3, rmse_rr[i]))
    print("Training took {} s".format(round(elapsed_rr[i],2)))
print("\n",'-'*68,"\n")
print("Lasso Regression")
for i in range(2):
    print("The RMSE for LASSO REGRESSION for df_train{} is {}".format(i+3, rmse_lr[i]))
    print("Training took {} s".format(round(elapsed_lr[i],2)))
print("\n",'-'*68,"\n")
# Out:
# BENCHMARK
# The RMSE for BENCHMARK for df_train1 is 0.612150270200498
# The RMSE for BENCHMARK for df_train2 is 0.612150270200498
# The RMSE for BENCHMARK for df_train3 is 0.5709465648655305
# The RMSE for BENCHMARK for df_train4 is 0.5709465648655305
# The RMSE for BENCHMARK for df_train5 is 0.5709465648655305
#
#  --------------------------------------------------------------------
#
# LIGHT GBM
# The RMSE for light GBM for df_train1 is 0.46548861110578665
# Training took 8.79 s
# The RMSE for light GBM for df_train2 is 0.464205793161556
# Training took 10.23 s
# The RMSE for light GBM for df_train3 is 0.4485461853903543
# Training took 8.61 s
# The RMSE for light GBM for df_train4 is 0.5651728176073144
# Training took 1.07 s
# The RMSE for light GBM for df_train5 is 0.45738539685426666
# Training took 1.19 s
#
#  --------------------------------------------------------------------
#
# XGBOOST
# The RMSE for XGBoost for df_train1 is 0.4140799690031782
# Training took 64.44 s
# The RMSE for XGBoost for df_train2 is 0.40942231376312505
# Training took 73.18 s
# The RMSE for XGBoost for df_train3 is 0.39548621998248024
# Training took 81.86 s
# The RMSE for XGBoost for df_train4 is 0.5460140063788276
# Training took 11.42 s
# The RMSE for XGBoost for df_train5 is 0.42418695140737794
# Training took 9.36 s
#
#  --------------------------------------------------------------------
#
# RANDOM FOREST REGRESSOR
# The RMSE for light RFR for df_train3 is 0.47643443717211803
# Training took 80.29 s
# The RMSE for light RFR for df_train4 is 0.6219574804018945
# Training took 17.89 s
#
#  --------------------------------------------------------------------
#
# Ridge Regression
# The RMSE for RIDGE REGRESSION for df_train3 is 0.4579025186823458
# Training took 0.48 s
# The RMSE for RIDGE REGRESSION for df_train4 is 0.5635890716840916
# Training took 0.02 s
#
#  --------------------------------------------------------------------
#
# Lasso Regression
# The RMSE for LASSO REGRESSION for df_train3 is 0.5709465648655311
# Training took 0.27 s
# The RMSE for LASSO REGRESSION for df_train4 is 0.5709465648655311
# Training took 0.04 s
#
#  --------------------------------------------------------------------

# %% [markdown]
# # XGBoost looks the most promising as out of the box algorithm
# ### All algos are better than the benchmark of just guessing the mean price
#
# # Now lets improve the XGBoost by applying grid search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
#rmse_xgboost = []
#elapsed_xgboost = []

#clf = GridSearchCV(xgb_model, xgb_params, verbose=1)
#clf.fit(df_train2,y_log)
#clf.best_score_, clf.best_params_

scorer = make_scorer(mean_squared_error, greater_is_better=False)

xgb_params = {
    "n_jobs" : 4,
     "n_estimators" : 100,
    'learning_rate': 0.05,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    "min_child_weight":1, 
    "gamma":0,
    'objective': 'reg:linear',
    'silent': 1
}

xgb_model = xgb.XGBRegressor(**xgb_params)


X_train, X_test, y_train, y_test = train_test_split(df_train3, y_log_imputation, test_size=0.2, random_state = 1234)

# %%
param_test1 = { 'max_depth':range(3,10,2),
                'min_child_weight':range(1,6,2)}

optimized_GBM1 = GridSearchCV(xgb_model, param_grid = param_test1, scoring = scorer, cv = 5, n_jobs = 4) 
optimized_GBM1.fit(X_train,y_train)
optimized_GBM1.grid_scores_, optimized_GBM1.best_params_, (optimized_GBM1.best_score_*-1)**0.5
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: -0.22504, std: 0.00451, params: {'max_depth': 3, 'min_child_weight': 1},
#   mean: -0.22532, std: 0.00451, params: {'max_depth': 3, 'min_child_weight': 3},
#   mean: -0.22472, std: 0.00442, params: {'max_depth': 3, 'min_child_weight': 5},
#   mean: -0.22271, std: 0.00441, params: {'max_depth': 5, 'min_child_weight': 1},
#   mean: -0.22186, std: 0.00411, params: {'max_depth': 5, 'min_child_weight': 3},
#   mean: -0.22145, std: 0.00415, params: {'max_depth': 5, 'min_child_weight': 5},
#   mean: -0.22296, std: 0.00458, params: {'max_depth': 7, 'min_child_weight': 1},
#   mean: -0.22225, std: 0.00352, params: {'max_depth': 7, 'min_child_weight': 3},
#   mean: -0.22181, std: 0.00423, params: {'max_depth': 7, 'min_child_weight': 5},
#   mean: -0.22466, std: 0.00437, params: {'max_depth': 9, 'min_child_weight': 1},
#   mean: -0.22409, std: 0.00360, params: {'max_depth': 9, 'min_child_weight': 3},
#   mean: -0.22248, std: 0.00343, params: {'max_depth': 9, 'min_child_weight': 5}],
#  {'max_depth': 5, 'min_child_weight': 5},
#  0.47058647047405894)

# %%
param_test2 = { 'max_depth': [4,5,6],
                'min_child_weight': [4,5,6]}

optimized_GBM2 = GridSearchCV(xgb_model, param_grid = param_test2, scoring = scorer, cv = 5, n_jobs = 4) 
optimized_GBM2.fit(X_train,y_train)
optimized_GBM2.grid_scores_, optimized_GBM2.best_params_, (optimized_GBM2.best_score_*-1)**0.5
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: -0.22253, std: 0.00454, params: {'max_depth': 4, 'min_child_weight': 4},
#   mean: -0.22257, std: 0.00477, params: {'max_depth': 4, 'min_child_weight': 5},
#   mean: -0.22245, std: 0.00447, params: {'max_depth': 4, 'min_child_weight': 6},
#   mean: -0.22179, std: 0.00443, params: {'max_depth': 5, 'min_child_weight': 4},
#   mean: -0.22145, std: 0.00415, params: {'max_depth': 5, 'min_child_weight': 5},
#   mean: -0.22119, std: 0.00462, params: {'max_depth': 5, 'min_child_weight': 6},
#   mean: -0.22160, std: 0.00455, params: {'max_depth': 6, 'min_child_weight': 4},
#   mean: -0.22077, std: 0.00412, params: {'max_depth': 6, 'min_child_weight': 5},
#   mean: -0.22112, std: 0.00457, params: {'max_depth': 6, 'min_child_weight': 6}],
#  {'max_depth': 6, 'min_child_weight': 5},
#  0.46986457846928686)

# %%
xgb_params = {
    "n_estimators" : 100,
    'learning_rate': 0.05,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    "min_child_weight":5, #grid searched
    "max_depth" : 6, #grid searched
    "gamma":0,
    'objective': 'reg:linear',
    'silent': 1,
    "n_jobs" : 4,
}

xgb_model = xgb.XGBRegressor(**xgb_params)

param_test3 = {'gamma':[i/100.0 for i in range(0,5)]}

optimized_GBM3 = GridSearchCV(xgb_model, param_grid = param_test3, scoring = scorer, cv = 5, n_jobs = 4) 
optimized_GBM3.fit(X_train,y_train)
optimized_GBM3.grid_scores_, optimized_GBM3.best_params_, (optimized_GBM3.best_score_*-1)**0.5
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: -0.22077, std: 0.00412, params: {'gamma': 0.0},
#   mean: -0.22072, std: 0.00413, params: {'gamma': 0.01},
#   mean: -0.22097, std: 0.00427, params: {'gamma': 0.02},
#   mean: -0.22077, std: 0.00447, params: {'gamma': 0.03},
#   mean: -0.22116, std: 0.00408, params: {'gamma': 0.04}],
#  {'gamma': 0.01},
#  0.46980745216770498)

# %%
xgb_params = {
    "n_estimators" : 100,
    'learning_rate': 0.05,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    "min_child_weight":5, #grid searched
    "max_depth" : 6, #grid searched
    "gamma":0.01, #
    'objective': 'reg:linear',
    'silent': 1,
    "n_jobs" : 4,
}

xgb_model = xgb.XGBRegressor(**xgb_params)

param_test4 = {'subsample':[i/10.0 for i in range(6,10)],
               'colsample_bytree':[i/10.0 for i in range(6,10)]}

optimized_GBM4 = GridSearchCV(xgb_model, param_grid = param_test4, scoring = scorer, cv = 5, n_jobs = 4) 
optimized_GBM4.fit(X_train,y_train)
optimized_GBM4.grid_scores_, optimized_GBM4.best_params_, (optimized_GBM4.best_score_*-1)**0.5
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: -0.22153, std: 0.00418, params: {'subsample': 0.6, 'colsample_bytree': 0.6},
#   mean: -0.22204, std: 0.00344, params: {'subsample': 0.7, 'colsample_bytree': 0.6},
#   mean: -0.22091, std: 0.00408, params: {'subsample': 0.8, 'colsample_bytree': 0.6},
#   mean: -0.22153, std: 0.00375, params: {'subsample': 0.9, 'colsample_bytree': 0.6},
#   mean: -0.22189, std: 0.00406, params: {'subsample': 0.6, 'colsample_bytree': 0.7},
#   mean: -0.22173, std: 0.00369, params: {'subsample': 0.7, 'colsample_bytree': 0.7},
#   mean: -0.22169, std: 0.00413, params: {'subsample': 0.8, 'colsample_bytree': 0.7},
#   mean: -0.22167, std: 0.00323, params: {'subsample': 0.9, 'colsample_bytree': 0.7},
#   mean: -0.22172, std: 0.00520, params: {'subsample': 0.6, 'colsample_bytree': 0.8},
#   mean: -0.22210, std: 0.00373, params: {'subsample': 0.7, 'colsample_bytree': 0.8},
#   mean: -0.22072, std: 0.00413, params: {'subsample': 0.8, 'colsample_bytree': 0.8},
#   mean: -0.22160, std: 0.00387, params: {'subsample': 0.9, 'colsample_bytree': 0.8},
#   mean: -0.22197, std: 0.00420, params: {'subsample': 0.6, 'colsample_bytree': 0.9},
#   mean: -0.22141, std: 0.00412, params: {'subsample': 0.7, 'colsample_bytree': 0.9},
#   mean: -0.22109, std: 0.00428, params: {'subsample': 0.8, 'colsample_bytree': 0.9},
#   mean: -0.22146, std: 0.00386, params: {'subsample': 0.9, 'colsample_bytree': 0.9}],
#  {'colsample_bytree': 0.8, 'subsample': 0.8},
#  0.46980745216770498)

# %%
xgb_params = {
    "n_estimators" : 100,
    'learning_rate': 0.05,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    "min_child_weight":5, #grid searched
    "max_depth" :6, #grid searched
    "gamma":0.01, #
    'objective': 'reg:linear',
    'silent': 1,
    "n_jobs" : 4,
}

xgb_model = xgb.XGBRegressor(**xgb_params)
param_test5 = {'subsample':[i/100.0 for i in range(79,83,1)],
               'colsample_bytree':[i/100.0 for i in range(79,83,1)]}

optimized_GBM5 = GridSearchCV(xgb_model, param_grid = param_test5, scoring = scorer, cv = 5, n_jobs = 4) 
optimized_GBM5.fit(X_train,y_train)
optimized_GBM5.grid_scores_, optimized_GBM5.best_params_, (optimized_GBM5.best_score_*-1)**0.5
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: -0.22125, std: 0.00399, params: {'subsample': 0.79, 'colsample_bytree': 0.79},
#   mean: -0.22140, std: 0.00440, params: {'subsample': 0.8, 'colsample_bytree': 0.79},
#   mean: -0.22135, std: 0.00412, params: {'subsample': 0.81, 'colsample_bytree': 0.79},
#   mean: -0.22150, std: 0.00426, params: {'subsample': 0.82, 'colsample_bytree': 0.79},
#   mean: -0.22151, std: 0.00417, params: {'subsample': 0.79, 'colsample_bytree': 0.8},
#   mean: -0.22072, std: 0.00413, params: {'subsample': 0.8, 'colsample_bytree': 0.8},
#   mean: -0.22144, std: 0.00452, params: {'subsample': 0.81, 'colsample_bytree': 0.8},
#   mean: -0.22112, std: 0.00457, params: {'subsample': 0.82, 'colsample_bytree': 0.8},
#   mean: -0.22124, std: 0.00461, params: {'subsample': 0.79, 'colsample_bytree': 0.81},
#   mean: -0.22089, std: 0.00422, params: {'subsample': 0.8, 'colsample_bytree': 0.81},
#   mean: -0.22141, std: 0.00441, params: {'subsample': 0.81, 'colsample_bytree': 0.81},
#   mean: -0.22144, std: 0.00353, params: {'subsample': 0.82, 'colsample_bytree': 0.81},
#   mean: -0.22126, std: 0.00426, params: {'subsample': 0.79, 'colsample_bytree': 0.82},
#   mean: -0.22126, std: 0.00403, params: {'subsample': 0.8, 'colsample_bytree': 0.82},
#   mean: -0.22121, std: 0.00410, params: {'subsample': 0.81, 'colsample_bytree': 0.82},
#   mean: -0.22166, std: 0.00430, params: {'subsample': 0.82, 'colsample_bytree': 0.82}],
#  {'colsample_bytree': 0.8, 'subsample': 0.8},
#  0.46980745216770498)

# %%
xgb_params = {
    "n_estimators" : 100,
    'learning_rate': 0.05,
    'subsample': 0.8, #grid
    'colsample_bytree': 0.8, #grid
    "min_child_weight":5, #grid searched
    "max_depth" : 6, #grid searched
    "gamma":0.01, #grid search
    'objective': 'reg:linear',
    'silent': 1,
    "n_jobs" : 4,
}

xgb_model = xgb.XGBRegressor(**xgb_params)

param_test6 = {'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100]}

optimized_GBM6 = GridSearchCV(xgb_model, param_grid = param_test6, scoring = scorer, cv = 5, n_jobs = 4) 
optimized_GBM6.fit(X_train,y_train)
optimized_GBM6.grid_scores_, optimized_GBM6.best_params_, (optimized_GBM6.best_score_*-1)**0.5
# Out:
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\xgboost-0.6-py3.5.egg\xgboost\sklearn.py:171: DeprecationWarning: The nthread parameter is deprecated as of version .6.Please use n_jobs instead.nthread is deprecated.
#   'nthread is deprecated.', DeprecationWarning)
# C:\Users\Wegee\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: -0.22072, std: 0.00413, params: {'reg_alpha': 1e-05},
#   mean: -0.22121, std: 0.00396, params: {'reg_alpha': 0.01},
#   mean: -0.22098, std: 0.00419, params: {'reg_alpha': 0.1},
#   mean: -0.22167, std: 0.00383, params: {'reg_alpha': 1},
#   mean: -0.24698, std: 0.00288, params: {'reg_alpha': 100}],
#  {'reg_alpha': 1e-05},
#  0.46980745627430431)

# %% [markdown]
# ### Finally, use the optimized model to predict prices of the test dataset and write .csv file for Kaggle submission.

# %%
df_train = [df_train2]
ylogs = [y_log]
rmse_xgboost = []
elapsed_xgboost = []

xgb_params = {
    "n_estimators" : 5000,
    'learning_rate': 0.01,
    'subsample': 0.8, #grid search
    'colsample_bytree': 0.8, #grid search
    "min_child_weight":5, #grid searched
    "max_depth" : 6, #grid searched
    "gamma":0.01, #grid search
    'reg_alpha': 1e-05, #grid search
    'objective': 'reg:linear',
    'silent': 1,
    "n_jobs" : 4,
}

for i in range(len(df_train)):
    X_train, X_test, y_train, y_test = train_test_split(df_train[i], ylogs[i], test_size=0.2, random_state = 1234)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 1234)
    
    df_columns = df_train[i].columns
    dtrain_all = xgb.DMatrix(df_train[i], ylogs[i], feature_names=df_columns)
    dtrain = xgb.DMatrix(X_train, y_train, feature_names=df_columns)
    dval = xgb.DMatrix(X_val, y_val, feature_names=df_columns)
    dtest = xgb.DMatrix(X_test, feature_names=df_columns)
    
    partial_model = xgb.train(xgb_params, dtrain, num_boost_round=1000, evals=[(dval, 'val')],
                       early_stopping_rounds=20, verbose_eval=20)

    num_boost_round = partial_model.best_iteration
    model = xgb.train(dict(xgb_params, silent=0), dtrain_all, num_boost_round=num_boost_round)
# Out:
# [0]	val-rmse:14.9389
# Will train until val-rmse hasn't improved in 20 rounds.
# [20]	val-rmse:12.2207
# [40]	val-rmse:9.99855
# [60]	val-rmse:8.18177
# [80]	val-rmse:6.69721
# [100]	val-rmse:5.48417
# [120]	val-rmse:4.49374
# [140]	val-rmse:3.68543
# [160]	val-rmse:3.02682
# [180]	val-rmse:2.49103
# [200]	val-rmse:2.05621
# [220]	val-rmse:1.70448
# [240]	val-rmse:1.42177
# [260]	val-rmse:1.19558
# [280]	val-rmse:1.01687
# [300]	val-rmse:0.877163
# [320]	val-rmse:0.769696
# [340]	val-rmse:0.68848
# [360]	val-rmse:0.628536
# [380]	val-rmse:0.584955
# [400]	val-rmse:0.554142
# [420]	val-rmse:0.532522
# [440]	val-rmse:0.517699
# [460]	val-rmse:0.507557
# [480]	val-rmse:0.500633
# [500]	val-rmse:0.496123
# [520]	val-rmse:0.493118
# [540]	val-rmse:0.49096
# [560]	val-rmse:0.489585
# [580]	val-rmse:0.488691
# [600]	val-rmse:0.488196
# [620]	val-rmse:0.487881
# [640]	val-rmse:0.487594
# [660]	val-rmse:0.487451
# [680]	val-rmse:0.487341
# [700]	val-rmse:0.487349
# [720]	val-rmse:0.487375
# Stopping. Best iteration:
# [702]	val-rmse:0.487296

# %%
dtest = xgb.DMatrix(df_test2, feature_names = df_columns)
y_pred = model.predict(dtest)

# %%
df_sub = pd.DataFrame({'id': id_test, 'price_doc': y_pred_})
df_sub.to_csv('submission.csv', index=False)
